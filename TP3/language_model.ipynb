# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections
import numpy as np

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = counter.keys()
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
n = len(data)
train_prop = int(0.9 * n)
train_data, val_data = data[:train_prop], data[train_prop:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8  # taille maximale du contexte à considérer pour faire la prédiction du prochain caractère

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([204145])
# context is >s< target is >,<
# context is >s,< target is >
# <
# context is >s,
# < target is >I<
# context is >s,
# I< target is >l<
# context is >s,
# Il< target is >s<
# context is >s,
# Ils< target is > <
# context is >s,
# Ils < target is >c<
# context is >s,
# Ils c< target is >o<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4  
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    ix = torch.randint(low=0, high=len(data)-block_size-1, size=(batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([torch.as_tensor(data[i:i+block_size]).clone().detach() for i in ix])
    # y is the character after each starting position
    y = torch.stack([torch.as_tensor(data[i+1:i+block_size+1]).clone().detach() for i in ix])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.token_embedding_table(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)  #go on the forward function
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C) ; predictions of what comes next 
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
    
vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 5.137679576873779

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor([encode(['\n'])], dtype=torch.long)
idx_generated = m.generate(idx=prompt, max_new_tokens=100)
decoded_gen = decode(idx_generated[0].tolist())  
print(decoded_gen)
###
# Out:
# [3]
#
# )G(F(ÎG7
#
# ;Ww«ïIKK[G9bÀB;7ÔZU5pWt3?îzê
# Zû7àâËZ!5-F[HëK«mxMLWÉn8ÆSê_Rïcx.7P)(Ca5î.d-eZEn,jfJF8,U3ÂdOè

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10**4
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.2172, val loss 5.2462
# step 10: train loss 5.1619, val loss 5.2214
# step 20: train loss 5.1456, val loss 5.2130
# step 30: train loss 5.2029, val loss 5.1643
# step 40: train loss 5.1788, val loss 5.2046
# step 50: train loss 5.1305, val loss 5.2042
# step 60: train loss 5.1568, val loss 5.1188
# step 70: train loss 5.1429, val loss 5.1439
# step 80: train loss 5.1316, val loss 5.1117
# step 90: train loss 5.1205, val loss 5.1117
# step 100: train loss 5.0671, val loss 5.1074
# step 110: train loss 5.0321, val loss 5.0356
# step 120: train loss 5.0780, val loss 5.1235
# step 130: train loss 5.0711, val loss 5.0709
# step 140: train loss 5.0796, val loss 5.0623
# step 150: train loss 5.0893, val loss 5.0541
# step 160: train loss 5.0649, val loss 5.0223
# step 170: train loss 5.0967, val loss 5.0559
# step 180: train loss 4.9920, val loss 5.0837
# step 190: train loss 5.0155, val loss 5.1019
# step 200: train loss 4.9395, val loss 5.0495
# step 210: train loss 5.0060, val loss 4.9889
# step 220: train loss 5.0067, val loss 4.9820
# step 230: train loss 5.0034, val loss 5.0518
# step 240: train loss 4.9758, val loss 4.9999
# step 250: train loss 5.0131, val loss 4.9502
# step 260: train loss 4.9674, val loss 4.9494
# step 270: train loss 4.9944, val loss 5.0041
# step 280: train loss 4.9379, val loss 5.0059
# step 290: train loss 4.9326, val loss 4.9512
# step 300: train loss 4.9454, val loss 4.8495
# step 310: train loss 4.9341, val loss 4.9097
# step 320: train loss 4.9068, val loss 4.9075
# step 330: train loss 4.8779, val loss 4.8652
# step 340: train loss 4.9191, val loss 4.9401
# step 350: train loss 4.8772, val loss 4.8892
# step 360: train loss 4.8437, val loss 4.9430
# step 370: train loss 4.8639, val loss 4.8972
# step 380: train loss 4.8340, val loss 4.8687
# step 390: train loss 4.8143, val loss 4.9317
# step 400: train loss 4.8364, val loss 4.8223
# step 410: train loss 4.8396, val loss 4.8970
# step 420: train loss 4.8544, val loss 4.8368
# step 430: train loss 4.8740, val loss 4.8589
# step 440: train loss 4.8183, val loss 4.8402
# step 450: train loss 4.7952, val loss 4.8175
# step 460: train loss 4.8009, val loss 4.8255
# step 470: train loss 4.7594, val loss 4.8027
# step 480: train loss 4.8328, val loss 4.8327
# step 490: train loss 4.7611, val loss 4.7572
# step 500: train loss 4.7360, val loss 4.7576
# step 510: train loss 4.8169, val loss 4.7295
# step 520: train loss 4.7546, val loss 4.7151
# step 530: train loss 4.6971, val loss 4.7115
# step 540: train loss 4.7331, val loss 4.7911
# step 550: train loss 4.6791, val loss 4.7863
# step 560: train loss 4.6875, val loss 4.7835
# step 570: train loss 4.6826, val loss 4.7695
# step 580: train loss 4.7316, val loss 4.7425
# step 590: train loss 4.6533, val loss 4.7294
# step 600: train loss 4.7728, val loss 4.6764
# step 610: train loss 4.7085, val loss 4.6661
# step 620: train loss 4.6942, val loss 4.7342
# step 630: train loss 4.6323, val loss 4.7080
# step 640: train loss 4.7131, val loss 4.6176
# step 650: train loss 4.6055, val loss 4.6308
# step 660: train loss 4.6077, val loss 4.7162
# step 670: train loss 4.5577, val loss 4.6376
# step 680: train loss 4.6028, val loss 4.6610
# step 690: train loss 4.5865, val loss 4.5726
# step 700: train loss 4.6234, val loss 4.6445
# step 710: train loss 4.6031, val loss 4.6216
# step 720: train loss 4.5950, val loss 4.6145
# step 730: train loss 4.4875, val loss 4.6003
# step 740: train loss 4.5783, val loss 4.5742
# step 750: train loss 4.5522, val loss 4.6177
# step 760: train loss 4.5156, val loss 4.6106
# step 770: train loss 4.6058, val loss 4.5493
# step 780: train loss 4.4747, val loss 4.5343
# step 790: train loss 4.6081, val loss 4.5556
# step 800: train loss 4.5648, val loss 4.5632
# step 810: train loss 4.5347, val loss 4.5997
# step 820: train loss 4.5373, val loss 4.5240
# step 830: train loss 4.4891, val loss 4.4251
# step 840: train loss 4.4346, val loss 4.4866
# step 850: train loss 4.5244, val loss 4.5251
# step 860: train loss 4.5456, val loss 4.4781
# step 870: train loss 4.4798, val loss 4.4859
# step 880: train loss 4.5135, val loss 4.5411
# step 890: train loss 4.5120, val loss 4.5423
# step 900: train loss 4.5008, val loss 4.5129
# step 910: train loss 4.4579, val loss 4.4832
# step 920: train loss 4.3990, val loss 4.4552
# step 930: train loss 4.4467, val loss 4.4408
# step 940: train loss 4.3147, val loss 4.4539
# step 950: train loss 4.4734, val loss 4.4943
# step 960: train loss 4.3848, val loss 4.4387
# step 970: train loss 4.4085, val loss 4.4185
# step 980: train loss 4.4008, val loss 4.4732
# step 990: train loss 4.4204, val loss 4.4033
# step 1000: train loss 4.3894, val loss 4.4429
# step 1010: train loss 4.3222, val loss 4.4983
# step 1020: train loss 4.3916, val loss 4.3744
# step 1030: train loss 4.3142, val loss 4.3904
# step 1040: train loss 4.3475, val loss 4.3244
# step 1050: train loss 4.3643, val loss 4.4481
# step 1060: train loss 4.3238, val loss 4.3934
# step 1070: train loss 4.3073, val loss 4.3512
# step 1080: train loss 4.3719, val loss 4.4147
# step 1090: train loss 4.3215, val loss 4.4024
# step 1100: train loss 4.3178, val loss 4.3749
# step 1110: train loss 4.3369, val loss 4.3727
# step 1120: train loss 4.3187, val loss 4.4033
# step 1130: train loss 4.2978, val loss 4.4000
# step 1140: train loss 4.1958, val loss 4.3097
# step 1150: train loss 4.3085, val loss 4.2932
# step 1160: train loss 4.2679, val loss 4.3760
# step 1170: train loss 4.2264, val loss 4.3298
# step 1180: train loss 4.2848, val loss 4.3212
# step 1190: train loss 4.2793, val loss 4.2698
# step 1200: train loss 4.2564, val loss 4.2639
# step 1210: train loss 4.2608, val loss 4.2415
# step 1220: train loss 4.2255, val loss 4.2706
# step 1230: train loss 4.3038, val loss 4.2256
# step 1240: train loss 4.1992, val loss 4.2468
# step 1250: train loss 4.2008, val loss 4.2218
# step 1260: train loss 4.1927, val loss 4.2440
# step 1270: train loss 4.1306, val loss 4.2261
# step 1280: train loss 4.2166, val loss 4.2828
# step 1290: train loss 4.1616, val loss 4.2675
# step 1300: train loss 4.1747, val loss 4.1929
# step 1310: train loss 4.1453, val loss 4.2122
# step 1320: train loss 4.1446, val loss 4.2674
# step 1330: train loss 4.1680, val loss 4.2063
# step 1340: train loss 4.1602, val loss 4.2194
# step 1350: train loss 4.1485, val loss 4.2121
# step 1360: train loss 4.1015, val loss 4.1402
# step 1370: train loss 4.1428, val loss 4.2097
# step 1380: train loss 4.1159, val loss 4.1913
# step 1390: train loss 4.1766, val loss 4.2292
# step 1400: train loss 4.0439, val loss 4.1267
# step 1410: train loss 4.1128, val loss 4.1689
# step 1420: train loss 4.1091, val loss 4.1107
# step 1430: train loss 4.0635, val loss 4.0465
# step 1440: train loss 4.1044, val loss 4.1186
# step 1450: train loss 4.0562, val loss 4.1734
# step 1460: train loss 4.1078, val loss 4.2166
# step 1470: train loss 4.0622, val loss 4.0690
# step 1480: train loss 4.0773, val loss 4.1485
# step 1490: train loss 4.1094, val loss 4.0558
# step 1500: train loss 4.0519, val loss 4.1020
# step 1510: train loss 4.0539, val loss 4.0852
# step 1520: train loss 4.0618, val loss 4.0583
# step 1530: train loss 3.9877, val loss 4.0956
# step 1540: train loss 4.0467, val loss 4.0898
# step 1550: train loss 4.0439, val loss 4.1145
# step 1560: train loss 3.9919, val loss 4.0635
# step 1570: train loss 3.9639, val loss 4.1701
# step 1580: train loss 3.9963, val loss 4.0585
# step 1590: train loss 3.9946, val loss 4.0910
# step 1600: train loss 3.9627, val loss 4.0597
# step 1610: train loss 4.0110, val loss 4.0869
# step 1620: train loss 3.9569, val loss 3.9463
# step 1630: train loss 3.9786, val loss 3.9687
# step 1640: train loss 3.9441, val loss 3.9831
# step 1650: train loss 3.9575, val loss 3.9613
# step 1660: train loss 3.9471, val loss 4.0160
# step 1670: train loss 3.8990, val loss 4.0577
# step 1680: train loss 3.9399, val loss 4.0052
# step 1690: train loss 3.9574, val loss 3.9504
# step 1700: train loss 3.9540, val loss 4.0271
# step 1710: train loss 3.8679, val loss 4.0420
# step 1720: train loss 3.9691, val loss 3.9479
# step 1730: train loss 3.9101, val loss 4.0529
# step 1740: train loss 3.9086, val loss 4.0511
# step 1750: train loss 3.9097, val loss 3.9088
# step 1760: train loss 3.9854, val loss 3.9787
# step 1770: train loss 3.9763, val loss 3.9548
# step 1780: train loss 3.8988, val loss 3.9285
# step 1790: train loss 3.8951, val loss 4.0429
# step 1800: train loss 3.8557, val loss 3.8113
# step 1810: train loss 3.8307, val loss 3.9297
# step 1820: train loss 3.8476, val loss 4.0021
# step 1830: train loss 3.9069, val loss 3.8752
# step 1840: train loss 3.8617, val loss 3.9955
# step 1850: train loss 3.9259, val loss 3.8925
# step 1860: train loss 3.8453, val loss 3.9399
# step 1870: train loss 3.8275, val loss 3.9093
# step 1880: train loss 3.7627, val loss 3.8784
# step 1890: train loss 3.8198, val loss 3.8973
# step 1900: train loss 3.8413, val loss 3.9050
# step 1910: train loss 3.8053, val loss 3.8738
# step 1920: train loss 3.7808, val loss 3.8995
# step 1930: train loss 3.7637, val loss 3.8256
# step 1940: train loss 3.7327, val loss 3.9217
# step 1950: train loss 3.8294, val loss 3.8247
# step 1960: train loss 3.8588, val loss 3.8672
# step 1970: train loss 3.7713, val loss 3.8036
# step 1980: train loss 3.8247, val loss 3.8298
# step 1990: train loss 3.7791, val loss 3.8999
# step 2000: train loss 3.7789, val loss 3.9861
# step 2010: train loss 3.7381, val loss 3.8862
# step 2020: train loss 3.7413, val loss 3.8316
# step 2030: train loss 3.8097, val loss 3.8208
# step 2040: train loss 3.7534, val loss 3.8205
# step 2050: train loss 3.7086, val loss 3.8177
# step 2060: train loss 3.8149, val loss 3.8810
# step 2070: train loss 3.7383, val loss 3.8721
# step 2080: train loss 3.7150, val loss 3.8264
# step 2090: train loss 3.7361, val loss 3.7698
# step 2100: train loss 3.7346, val loss 3.8557
# step 2110: train loss 3.7263, val loss 3.7469
# step 2120: train loss 3.7454, val loss 3.7867
# step 2130: train loss 3.7497, val loss 3.7340
# step 2140: train loss 3.6593, val loss 3.7807
# step 2150: train loss 3.7489, val loss 3.7837
# step 2160: train loss 3.7119, val loss 3.7616
# step 2170: train loss 3.7500, val loss 3.7578
# step 2180: train loss 3.6269, val loss 3.7348
# step 2190: train loss 3.6534, val loss 3.7647
# step 2200: train loss 3.6933, val loss 3.7644
# step 2210: train loss 3.6426, val loss 3.7733
# step 2220: train loss 3.7232, val loss 3.7680
# step 2230: train loss 3.6705, val loss 3.7803
# step 2240: train loss 3.6543, val loss 3.7346
# step 2250: train loss 3.6926, val loss 3.6403
# step 2260: train loss 3.6029, val loss 3.6944
# step 2270: train loss 3.6723, val loss 3.7409
# step 2280: train loss 3.6535, val loss 3.7059
# step 2290: train loss 3.6523, val loss 3.5987
# step 2300: train loss 3.6106, val loss 3.7327
# step 2310: train loss 3.6901, val loss 3.6512
# step 2320: train loss 3.6498, val loss 3.6407
# step 2330: train loss 3.6199, val loss 3.6749
# step 2340: train loss 3.6102, val loss 3.8135
# step 2350: train loss 3.6179, val loss 3.7542
# step 2360: train loss 3.6226, val loss 3.6566
# step 2370: train loss 3.6001, val loss 3.6731
# step 2380: train loss 3.5879, val loss 3.6804
# step 2390: train loss 3.6015, val loss 3.6787
# step 2400: train loss 3.5051, val loss 3.7859
# step 2410: train loss 3.5644, val loss 3.7082
# step 2420: train loss 3.5356, val loss 3.6915
# step 2430: train loss 3.5308, val loss 3.7250
# step 2440: train loss 3.6156, val loss 3.5773
# step 2450: train loss 3.5833, val loss 3.6413
# step 2460: train loss 3.5916, val loss 3.6871
# step 2470: train loss 3.5242, val loss 3.5619
# step 2480: train loss 3.4993, val loss 3.6657
# step 2490: train loss 3.5751, val loss 3.6251
# step 2500: train loss 3.5375, val loss 3.5445
# step 2510: train loss 3.5863, val loss 3.6629
# step 2520: train loss 3.4455, val loss 3.5809
# step 2530: train loss 3.5440, val loss 3.5894
# step 2540: train loss 3.5854, val loss 3.6503
# step 2550: train loss 3.5114, val loss 3.5014
# step 2560: train loss 3.5365, val loss 3.7072
# step 2570: train loss 3.4767, val loss 3.6729
# step 2580: train loss 3.5244, val loss 3.6067
# step 2590: train loss 3.5137, val loss 3.6636
# step 2600: train loss 3.5060, val loss 3.4800
# step 2610: train loss 3.5300, val loss 3.6083
# step 2620: train loss 3.4831, val loss 3.5891
# step 2630: train loss 3.4738, val loss 3.5435
# step 2640: train loss 3.5210, val loss 3.5786
# step 2650: train loss 3.4610, val loss 3.5038
# step 2660: train loss 3.5074, val loss 3.6144
# step 2670: train loss 3.4443, val loss 3.5249
# step 2680: train loss 3.5002, val loss 3.4488
# step 2690: train loss 3.4013, val loss 3.5944
# step 2700: train loss 3.4076, val loss 3.5177
# step 2710: train loss 3.4434, val loss 3.6429
# step 2720: train loss 3.4630, val loss 3.5797
# step 2730: train loss 3.5010, val loss 3.4917
# step 2740: train loss 3.4675, val loss 3.6385
# step 2750: train loss 3.4223, val loss 3.4696
# step 2760: train loss 3.5228, val loss 3.4966
# step 2770: train loss 3.4350, val loss 3.5728
# step 2780: train loss 3.4408, val loss 3.4872
# step 2790: train loss 3.4719, val loss 3.6503
# step 2800: train loss 3.3682, val loss 3.5261
# step 2810: train loss 3.4238, val loss 3.5103
# step 2820: train loss 3.4313, val loss 3.4892
# step 2830: train loss 3.4419, val loss 3.4174
# step 2840: train loss 3.4417, val loss 3.5565
# step 2850: train loss 3.4287, val loss 3.4828
# step 2860: train loss 3.4529, val loss 3.4591
# step 2870: train loss 3.4105, val loss 3.4681
# step 2880: train loss 3.3852, val loss 3.4251
# step 2890: train loss 3.3977, val loss 3.4826
# step 2900: train loss 3.4854, val loss 3.6080
# step 2910: train loss 3.4122, val loss 3.4625
# step 2920: train loss 3.3453, val loss 3.5406
# step 2930: train loss 3.3295, val loss 3.4162
# step 2940: train loss 3.4237, val loss 3.5670
# step 2950: train loss 3.4527, val loss 3.5007
# step 2960: train loss 3.3690, val loss 3.3777
# step 2970: train loss 3.4632, val loss 3.4252
# step 2980: train loss 3.3778, val loss 3.5317
# step 2990: train loss 3.3921, val loss 3.4452
# step 3000: train loss 3.3739, val loss 3.4696
# step 3010: train loss 3.3712, val loss 3.3813
# step 3020: train loss 3.3922, val loss 3.4102
# step 3030: train loss 3.3787, val loss 3.4857
# step 3040: train loss 3.3467, val loss 3.3683
# step 3050: train loss 3.3216, val loss 3.4045
# step 3060: train loss 3.4140, val loss 3.3556
# step 3070: train loss 3.3324, val loss 3.3432
# step 3080: train loss 3.4170, val loss 3.3335
# step 3090: train loss 3.3099, val loss 3.3451
# step 3100: train loss 3.3714, val loss 3.3785
# step 3110: train loss 3.3229, val loss 3.3760
# step 3120: train loss 3.3700, val loss 3.3808
# step 3130: train loss 3.3613, val loss 3.3641
# step 3140: train loss 3.2591, val loss 3.4528
# step 3150: train loss 3.3179, val loss 3.3431
# step 3160: train loss 3.3559, val loss 3.3932
# step 3170: train loss 3.3586, val loss 3.3871
# step 3180: train loss 3.3408, val loss 3.3467
# step 3190: train loss 3.2364, val loss 3.3915
# step 3200: train loss 3.2314, val loss 3.4204
# step 3210: train loss 3.2245, val loss 3.3321
# step 3220: train loss 3.2754, val loss 3.4094
# step 3230: train loss 3.2982, val loss 3.3876
# step 3240: train loss 3.3073, val loss 3.3926
# step 3250: train loss 3.3530, val loss 3.3340
# step 3260: train loss 3.2533, val loss 3.3285
# step 3270: train loss 3.3499, val loss 3.3664
# step 3280: train loss 3.2705, val loss 3.2920
# step 3290: train loss 3.2482, val loss 3.2730
# step 3300: train loss 3.3036, val loss 3.3203
# step 3310: train loss 3.2398, val loss 3.3756
# step 3320: train loss 3.2446, val loss 3.3469
# step 3330: train loss 3.1937, val loss 3.2427
# step 3340: train loss 3.2189, val loss 3.2690
# step 3350: train loss 3.1806, val loss 3.2648
# step 3360: train loss 3.2541, val loss 3.3933
# step 3370: train loss 3.2153, val loss 3.2995
# step 3380: train loss 3.2524, val loss 3.3238
# step 3390: train loss 3.2689, val loss 3.3705
# step 3400: train loss 3.1503, val loss 3.2971
# step 3410: train loss 3.2634, val loss 3.2969
# step 3420: train loss 3.2141, val loss 3.2497
# step 3430: train loss 3.2446, val loss 3.3447
# step 3440: train loss 3.2450, val loss 3.3673
# step 3450: train loss 3.1936, val loss 3.2389
# step 3460: train loss 3.2440, val loss 3.3573
# step 3470: train loss 3.2318, val loss 3.3242
# step 3480: train loss 3.2371, val loss 3.3656
# step 3490: train loss 3.1885, val loss 3.3371
# step 3500: train loss 3.2879, val loss 3.3164
# step 3510: train loss 3.1414, val loss 3.3400
# step 3520: train loss 3.2122, val loss 3.2973
# step 3530: train loss 3.2079, val loss 3.2543
# step 3540: train loss 3.1571, val loss 3.3721
# step 3550: train loss 3.1849, val loss 3.3021
# step 3560: train loss 3.1520, val loss 3.2170
# step 3570: train loss 3.1888, val loss 3.2739
# step 3580: train loss 3.1493, val loss 3.3678
# step 3590: train loss 3.1799, val loss 3.1826
# step 3600: train loss 3.1805, val loss 3.1938
# step 3610: train loss 3.0896, val loss 3.2794
# step 3620: train loss 3.1276, val loss 3.1770
# step 3630: train loss 3.1278, val loss 3.2869
# step 3640: train loss 3.1773, val loss 3.2564
# step 3650: train loss 3.1355, val loss 3.2304
# step 3660: train loss 3.0922, val loss 3.2207
# step 3670: train loss 3.1377, val loss 3.2044
# step 3680: train loss 3.1279, val loss 3.2879
# step 3690: train loss 3.1029, val loss 3.2808
# step 3700: train loss 3.1147, val loss 3.4110
# step 3710: train loss 3.1547, val loss 3.2584
# step 3720: train loss 3.1509, val loss 3.2832
# step 3730: train loss 3.1026, val loss 3.1857
# step 3740: train loss 3.1888, val loss 3.1931
# step 3750: train loss 3.1815, val loss 3.2556
# step 3760: train loss 3.0582, val loss 3.1617
# step 3770: train loss 3.0430, val loss 3.2201
# step 3780: train loss 3.1635, val loss 3.2118
# step 3790: train loss 3.1790, val loss 3.1861
# step 3800: train loss 3.1130, val loss 3.2392
# step 3810: train loss 3.1123, val loss 3.2818
# step 3820: train loss 3.0604, val loss 3.2011
# step 3830: train loss 3.0712, val loss 3.1957
# step 3840: train loss 3.1438, val loss 3.1073
# step 3850: train loss 3.1031, val loss 3.2155
# step 3860: train loss 3.0858, val loss 3.0676
# step 3870: train loss 3.1087, val loss 3.2259
# step 3880: train loss 3.1129, val loss 3.1589
# step 3890: train loss 3.1520, val loss 3.0994
# step 3900: train loss 2.9706, val loss 3.1904
# step 3910: train loss 3.1286, val loss 3.1949
# step 3920: train loss 3.0703, val loss 3.1346
# step 3930: train loss 3.0832, val loss 3.2273
# step 3940: train loss 3.0352, val loss 3.2485
# step 3950: train loss 3.0656, val loss 3.2030
# step 3960: train loss 3.1441, val loss 3.1486
# step 3970: train loss 3.1073, val loss 3.1487
# step 3980: train loss 3.0566, val loss 3.2060
# step 3990: train loss 3.1022, val loss 3.1900
# step 4000: train loss 3.0218, val loss 3.0972
# step 4010: train loss 3.0862, val loss 3.0411
# step 4020: train loss 3.0277, val loss 3.1037
# step 4030: train loss 3.0738, val loss 3.1279
# step 4040: train loss 3.0467, val loss 3.0613
# step 4050: train loss 3.0394, val loss 3.1149
# step 4060: train loss 3.0896, val loss 3.0440
# step 4070: train loss 3.0363, val loss 3.1063
# step 4080: train loss 2.9644, val loss 3.0972
# step 4090: train loss 3.0660, val loss 3.1426
# step 4100: train loss 3.0232, val loss 3.1539
# step 4110: train loss 2.9954, val loss 3.1340
# step 4120: train loss 2.9630, val loss 3.1111
# step 4130: train loss 3.0031, val loss 3.1493
# step 4140: train loss 2.9919, val loss 3.1590
# step 4150: train loss 3.0092, val loss 3.1304
# step 4160: train loss 3.0540, val loss 3.1890
# step 4170: train loss 3.0035, val loss 3.1501
# step 4180: train loss 2.9801, val loss 3.0861
# step 4190: train loss 3.1168, val loss 3.1127
# step 4200: train loss 2.9841, val loss 3.0703
# step 4210: train loss 2.9793, val loss 3.1628
# step 4220: train loss 3.0123, val loss 3.1993
# step 4230: train loss 2.9447, val loss 3.2238
# step 4240: train loss 2.9886, val loss 3.0803
# step 4250: train loss 3.0258, val loss 3.1784
# step 4260: train loss 3.0027, val loss 3.1214
# step 4270: train loss 3.0402, val loss 3.1298
# step 4280: train loss 3.0555, val loss 3.1427
# step 4290: train loss 3.0838, val loss 3.0326
# step 4300: train loss 2.9798, val loss 3.0385
# step 4310: train loss 2.9958, val loss 3.1148
# step 4320: train loss 3.0013, val loss 3.0746
# step 4330: train loss 2.9165, val loss 3.0925
# step 4340: train loss 2.9388, val loss 3.0753
# step 4350: train loss 3.0176, val loss 2.9871
# step 4360: train loss 3.0230, val loss 3.0341
# step 4370: train loss 2.9543, val loss 2.9826
# step 4380: train loss 3.0052, val loss 3.0978
# step 4390: train loss 3.0247, val loss 3.0207
# step 4400: train loss 2.9799, val loss 3.0217
# step 4410: train loss 2.9695, val loss 3.1114
# step 4420: train loss 2.9591, val loss 3.0749
# step 4430: train loss 2.9342, val loss 3.0623
# step 4440: train loss 2.9311, val loss 3.0087
# step 4450: train loss 2.9368, val loss 3.0424
# step 4460: train loss 2.9197, val loss 3.1394
# step 4470: train loss 2.9826, val loss 3.0873
# step 4480: train loss 2.9724, val loss 3.1037
# step 4490: train loss 2.9647, val loss 3.1010
# step 4500: train loss 2.9846, val loss 3.0435
# step 4510: train loss 2.9389, val loss 3.0109
# step 4520: train loss 2.9580, val loss 3.0748
# step 4530: train loss 3.0403, val loss 2.9693
# step 4540: train loss 2.8869, val loss 3.1381
# step 4550: train loss 2.9285, val loss 3.0800
# step 4560: train loss 2.9906, val loss 3.0942
# step 4570: train loss 2.9872, val loss 3.0669
# step 4580: train loss 2.8642, val loss 3.0631
# step 4590: train loss 2.9403, val loss 3.0913
# step 4600: train loss 2.9216, val loss 2.9600
# step 4610: train loss 2.9346, val loss 3.0566
# step 4620: train loss 2.9156, val loss 3.0310
# step 4630: train loss 2.8736, val loss 3.0315
# step 4640: train loss 2.9264, val loss 3.0190
# step 4650: train loss 2.9492, val loss 3.0048
# step 4660: train loss 2.9628, val loss 3.0511
# step 4670: train loss 2.9323, val loss 3.0430
# step 4680: train loss 2.8518, val loss 3.0129
# step 4690: train loss 2.9540, val loss 3.1489
# step 4700: train loss 2.9561, val loss 2.9722
# step 4710: train loss 2.8797, val loss 3.0029
# step 4720: train loss 2.9004, val loss 2.8951
# step 4730: train loss 2.9238, val loss 2.9057
# step 4740: train loss 2.8982, val loss 2.9701
# step 4750: train loss 2.8683, val loss 2.9508
# step 4760: train loss 2.8375, val loss 2.9948
# step 4770: train loss 2.9585, val loss 2.9290
# step 4780: train loss 2.8138, val loss 3.0037
# step 4790: train loss 3.0116, val loss 2.9648
# step 4800: train loss 2.8650, val loss 2.9234
# step 4810: train loss 2.9740, val loss 3.0147
# step 4820: train loss 2.9580, val loss 2.9474
# step 4830: train loss 2.8884, val loss 3.0588
# step 4840: train loss 2.8878, val loss 2.8465
# step 4850: train loss 2.8277, val loss 2.9389
# step 4860: train loss 2.9174, val loss 3.0335
# step 4870: train loss 2.8450, val loss 2.9987
# step 4880: train loss 2.9332, val loss 2.9848
# step 4890: train loss 2.8976, val loss 2.9571
# step 4900: train loss 2.8513, val loss 2.9728
# step 4910: train loss 2.8432, val loss 2.9526
# step 4920: train loss 2.9260, val loss 2.9298
# step 4930: train loss 2.9099, val loss 3.0025
# step 4940: train loss 2.8670, val loss 2.9497
# step 4950: train loss 2.8085, val loss 2.9685
# step 4960: train loss 2.8900, val loss 2.9813
# step 4970: train loss 2.7886, val loss 2.8742
# step 4980: train loss 2.8639, val loss 3.0156
# step 4990: train loss 2.8519, val loss 3.0670
# step 5000: train loss 2.8555, val loss 2.9228
# step 5010: train loss 2.8467, val loss 3.0361
# step 5020: train loss 2.8618, val loss 2.8896
# step 5030: train loss 2.8366, val loss 2.9537
# step 5040: train loss 2.9112, val loss 2.8986
# step 5050: train loss 2.8021, val loss 2.9417
# step 5060: train loss 2.8995, val loss 3.0534
# step 5070: train loss 2.8895, val loss 3.0030
# step 5080: train loss 2.7672, val loss 2.9866
# step 5090: train loss 2.8933, val loss 2.9963
# step 5100: train loss 2.7853, val loss 2.8866
# step 5110: train loss 2.8344, val loss 2.9147
# step 5120: train loss 2.8930, val loss 2.9386
# step 5130: train loss 2.8663, val loss 2.9680
# step 5140: train loss 2.8792, val loss 2.9703
# step 5150: train loss 2.7792, val loss 2.8394
# step 5160: train loss 2.8242, val loss 3.0958
# step 5170: train loss 2.8405, val loss 2.8671
# step 5180: train loss 2.8868, val loss 2.9097
# step 5190: train loss 2.7979, val loss 2.8923
# step 5200: train loss 2.7868, val loss 2.8883
# step 5210: train loss 2.8682, val loss 2.9978
# step 5220: train loss 2.8789, val loss 2.9118
# step 5230: train loss 2.7669, val loss 2.9062
# step 5240: train loss 2.8468, val loss 2.9859
# step 5250: train loss 2.9313, val loss 2.8904
# step 5260: train loss 2.7881, val loss 2.9637
# step 5270: train loss 2.7326, val loss 2.8091
# step 5280: train loss 2.7686, val loss 2.8040
# step 5290: train loss 2.8513, val loss 2.9253
# step 5300: train loss 2.7535, val loss 2.8819
# step 5310: train loss 2.8404, val loss 3.0231
# step 5320: train loss 2.7586, val loss 2.9367
# step 5330: train loss 2.7646, val loss 2.9966
# step 5340: train loss 2.8067, val loss 2.9935
# step 5350: train loss 2.8067, val loss 2.9244
# step 5360: train loss 2.8703, val loss 2.9015
# step 5370: train loss 2.8804, val loss 2.9548
# step 5380: train loss 2.8260, val loss 2.8923
# step 5390: train loss 2.8432, val loss 2.9688
# step 5400: train loss 2.7939, val loss 2.9279
# step 5410: train loss 2.7795, val loss 2.9920
# step 5420: train loss 2.7646, val loss 3.0009
# step 5430: train loss 2.8163, val loss 2.9189
# step 5440: train loss 2.8379, val loss 2.8325
# step 5450: train loss 2.8014, val loss 2.9099
# step 5460: train loss 2.7526, val loss 2.8645
# step 5470: train loss 2.8405, val loss 2.8898
# step 5480: train loss 2.7747, val loss 2.8825
# step 5490: train loss 2.7102, val loss 2.8698
# step 5500: train loss 2.9012, val loss 2.8702
# step 5510: train loss 2.8268, val loss 2.8331
# step 5520: train loss 2.8048, val loss 2.8536
# step 5530: train loss 2.7527, val loss 2.8785
# step 5540: train loss 2.8467, val loss 2.8748
# step 5550: train loss 2.7987, val loss 2.8254
# step 5560: train loss 2.7849, val loss 2.8306
# step 5570: train loss 2.9238, val loss 2.8525
# step 5580: train loss 2.7476, val loss 2.8751
# step 5590: train loss 2.7101, val loss 2.9179
# step 5600: train loss 2.7371, val loss 2.8224
# step 5610: train loss 2.6961, val loss 2.8183
# step 5620: train loss 2.7815, val loss 2.8068
# step 5630: train loss 2.8255, val loss 2.9145
# step 5640: train loss 2.7833, val loss 2.8309
# step 5650: train loss 2.7120, val loss 2.8355
# step 5660: train loss 2.7554, val loss 2.8289
# step 5670: train loss 2.7266, val loss 2.8480
# step 5680: train loss 2.7819, val loss 2.8373
# step 5690: train loss 2.7640, val loss 2.7971
# step 5700: train loss 2.8105, val loss 2.7601
# step 5710: train loss 2.8583, val loss 2.8690
# step 5720: train loss 2.7594, val loss 2.9060
# step 5730: train loss 2.6856, val loss 2.9907
# step 5740: train loss 2.7315, val loss 2.9959
# step 5750: train loss 2.7598, val loss 2.8356
# step 5760: train loss 2.7061, val loss 2.8531
# step 5770: train loss 2.8331, val loss 2.9286
# step 5780: train loss 2.6886, val loss 2.8566
# step 5790: train loss 2.7525, val loss 2.7623
# step 5800: train loss 2.7348, val loss 2.9856
# step 5810: train loss 2.8060, val loss 2.8553
# step 5820: train loss 2.7238, val loss 2.7882
# step 5830: train loss 2.7414, val loss 2.8635
# step 5840: train loss 2.6597, val loss 2.9842
# step 5850: train loss 2.7353, val loss 2.8016
# step 5860: train loss 2.7425, val loss 2.9011
# step 5870: train loss 2.8241, val loss 2.8731
# step 5880: train loss 2.7497, val loss 2.8830
# step 5890: train loss 2.7235, val loss 2.9043
# step 5900: train loss 2.7973, val loss 2.8031
# step 5910: train loss 2.7650, val loss 2.9360
# step 5920: train loss 2.7855, val loss 2.8554
# step 5930: train loss 2.7499, val loss 2.8349
# step 5940: train loss 2.8036, val loss 2.8386
# step 5950: train loss 2.7790, val loss 2.7685
# step 5960: train loss 2.7363, val loss 2.8638
# step 5970: train loss 2.7174, val loss 2.8907
# step 5980: train loss 2.7333, val loss 2.9850
# step 5990: train loss 2.7478, val loss 2.9035
# step 6000: train loss 2.7607, val loss 2.8284
# step 6010: train loss 2.6855, val loss 2.9935
# step 6020: train loss 2.6981, val loss 2.8800
# step 6030: train loss 2.6621, val loss 2.7132
# step 6040: train loss 2.6793, val loss 2.8914
# step 6050: train loss 2.6316, val loss 2.7410
# step 6060: train loss 2.7102, val loss 2.8796
# step 6070: train loss 2.7000, val loss 2.7801
# step 6080: train loss 2.7068, val loss 2.8172
# step 6090: train loss 2.8119, val loss 2.8386
# step 6100: train loss 2.8547, val loss 2.7798
# step 6110: train loss 2.8184, val loss 2.8831
# step 6120: train loss 2.6952, val loss 2.7172
# step 6130: train loss 2.8266, val loss 2.8201
# step 6140: train loss 2.8261, val loss 2.7353
# step 6150: train loss 2.6688, val loss 2.9552
# step 6160: train loss 2.7095, val loss 2.7545
# step 6170: train loss 2.7214, val loss 2.7213
# step 6180: train loss 2.7467, val loss 2.8210
# step 6190: train loss 2.6496, val loss 2.8158
# step 6200: train loss 2.6518, val loss 2.8855
# step 6210: train loss 2.7214, val loss 2.7919
# step 6220: train loss 2.6852, val loss 2.8466
# step 6230: train loss 2.6209, val loss 2.9159
# step 6240: train loss 2.7010, val loss 2.7773
# step 6250: train loss 2.6607, val loss 2.8076
# step 6260: train loss 2.7040, val loss 2.8520
# step 6270: train loss 2.7517, val loss 2.8504
# step 6280: train loss 2.7241, val loss 2.7753
# step 6290: train loss 2.7276, val loss 2.8064
# step 6300: train loss 2.6463, val loss 2.7659
# step 6310: train loss 2.7656, val loss 2.7977
# step 6320: train loss 2.6259, val loss 2.8270
# step 6330: train loss 2.6838, val loss 2.8332
# step 6340: train loss 2.6684, val loss 2.8848
# step 6350: train loss 2.6644, val loss 2.7212
# step 6360: train loss 2.6645, val loss 2.7506
# step 6370: train loss 2.6894, val loss 2.7161
# step 6380: train loss 2.6712, val loss 2.7710
# step 6390: train loss 2.6624, val loss 2.7194
# step 6400: train loss 2.7197, val loss 2.8760
# step 6410: train loss 2.7530, val loss 2.7354
# step 6420: train loss 2.6814, val loss 2.8225
# step 6430: train loss 2.7045, val loss 2.7963
# step 6440: train loss 2.7702, val loss 2.9027
# step 6450: train loss 2.6274, val loss 2.7538
# step 6460: train loss 2.7494, val loss 2.7538
# step 6470: train loss 2.7494, val loss 2.8037
# step 6480: train loss 2.6408, val loss 2.7603
# step 6490: train loss 2.8116, val loss 2.7802
# step 6500: train loss 2.6373, val loss 2.7603
# step 6510: train loss 2.6478, val loss 2.7308
# step 6520: train loss 2.6831, val loss 2.6994
# step 6530: train loss 2.7702, val loss 2.7479
# step 6540: train loss 2.6759, val loss 2.7761
# step 6550: train loss 2.7438, val loss 2.6689
# step 6560: train loss 2.7853, val loss 2.8126
# step 6570: train loss 2.6566, val loss 2.7311
# step 6580: train loss 2.7216, val loss 2.8231
# step 6590: train loss 2.7354, val loss 2.7711
# step 6600: train loss 2.7209, val loss 2.7218
# step 6610: train loss 2.6717, val loss 2.7303
# step 6620: train loss 2.6675, val loss 2.8426
# step 6630: train loss 2.7056, val loss 2.8272
# step 6640: train loss 2.7840, val loss 2.8961
# step 6650: train loss 2.6239, val loss 2.8069
# step 6660: train loss 2.6481, val loss 2.7762
# step 6670: train loss 2.6067, val loss 2.8370
# step 6680: train loss 2.5720, val loss 2.6855
# step 6690: train loss 2.5878, val loss 2.7837
# step 6700: train loss 2.5951, val loss 2.7549
# step 6710: train loss 2.6416, val loss 2.6875
# step 6720: train loss 2.7195, val loss 2.7403
# step 6730: train loss 2.7190, val loss 2.6694
# step 6740: train loss 2.6913, val loss 2.7316
# step 6750: train loss 2.5939, val loss 2.6656
# step 6760: train loss 2.6683, val loss 2.7389
# step 6770: train loss 2.7021, val loss 2.8208
# step 6780: train loss 2.6418, val loss 2.7183
# step 6790: train loss 2.7401, val loss 2.7212
# step 6800: train loss 2.6504, val loss 2.6883
# step 6810: train loss 2.7120, val loss 2.7914
# step 6820: train loss 2.5970, val loss 2.7392
# step 6830: train loss 2.6528, val loss 2.7760
# step 6840: train loss 2.6828, val loss 2.8246
# step 6850: train loss 2.6927, val loss 2.8044
# step 6860: train loss 2.6914, val loss 2.7224
# step 6870: train loss 2.6565, val loss 2.9160
# step 6880: train loss 2.6174, val loss 2.7777
# step 6890: train loss 2.6332, val loss 2.8473
# step 6900: train loss 2.6401, val loss 2.9494
# step 6910: train loss 2.6725, val loss 2.8152
# step 6920: train loss 2.7033, val loss 2.7388
# step 6930: train loss 2.5863, val loss 2.8563
# step 6940: train loss 2.6339, val loss 2.7290
# step 6950: train loss 2.7136, val loss 2.9567
# step 6960: train loss 2.7040, val loss 2.8048
# step 6970: train loss 2.6043, val loss 2.8232
# step 6980: train loss 2.5854, val loss 2.8528
# step 6990: train loss 2.6961, val loss 2.8471
# step 7000: train loss 2.6488, val loss 2.7134
# step 7010: train loss 2.6549, val loss 2.6894
# step 7020: train loss 2.6416, val loss 2.7607
# step 7030: train loss 2.6121, val loss 2.7218
# step 7040: train loss 2.7051, val loss 2.6915
# step 7050: train loss 2.6272, val loss 2.7743
# step 7060: train loss 2.5364, val loss 2.5904
# step 7070: train loss 2.6160, val loss 2.7726
# step 7080: train loss 2.6063, val loss 2.7020
# step 7090: train loss 2.6273, val loss 2.5753
# step 7100: train loss 2.5907, val loss 2.7355
# step 7110: train loss 2.7098, val loss 2.7298
# step 7120: train loss 2.7037, val loss 2.7734
# step 7130: train loss 2.6356, val loss 2.6868
# step 7140: train loss 2.7156, val loss 2.7809
# step 7150: train loss 2.6363, val loss 2.7145
# step 7160: train loss 2.6518, val loss 2.7745
# step 7170: train loss 2.5596, val loss 2.5850
# step 7180: train loss 2.6285, val loss 2.8208
# step 7190: train loss 2.6377, val loss 2.7850
# step 7200: train loss 2.6657, val loss 2.7910
# step 7210: train loss 2.6301, val loss 2.7303
# step 7220: train loss 2.5716, val loss 2.6600
# step 7230: train loss 2.6547, val loss 2.6781
# step 7240: train loss 2.6192, val loss 2.5399
# step 7250: train loss 2.5202, val loss 2.6545
# step 7260: train loss 2.6360, val loss 2.6210
# step 7270: train loss 2.5182, val loss 2.6597
# step 7280: train loss 2.6467, val loss 2.6311
# step 7290: train loss 2.6007, val loss 2.7926
# step 7300: train loss 2.6473, val loss 2.6509
# step 7310: train loss 2.6555, val loss 2.6369
# step 7320: train loss 2.5376, val loss 2.7349
# step 7330: train loss 2.6113, val loss 2.6407
# step 7340: train loss 2.6500, val loss 2.7194
# step 7350: train loss 2.6354, val loss 2.7406
# step 7360: train loss 2.5614, val loss 2.7116
# step 7370: train loss 2.6247, val loss 2.6511
# step 7380: train loss 2.6316, val loss 2.7452
# step 7390: train loss 2.6569, val loss 2.7822
# step 7400: train loss 2.6347, val loss 2.7629
# step 7410: train loss 2.6333, val loss 2.6499
# step 7420: train loss 2.6373, val loss 2.6841
# step 7430: train loss 2.5754, val loss 2.6429
# step 7440: train loss 2.6449, val loss 2.6465
# step 7450: train loss 2.5760, val loss 2.7473
# step 7460: train loss 2.6178, val loss 2.6759
# step 7470: train loss 2.5913, val loss 2.5777
# step 7480: train loss 2.6473, val loss 2.6401
# step 7490: train loss 2.5536, val loss 2.7453
# step 7500: train loss 2.5782, val loss 2.7143
# step 7510: train loss 2.5870, val loss 2.6219
# step 7520: train loss 2.5777, val loss 2.6961
# step 7530: train loss 2.6089, val loss 2.7540
# step 7540: train loss 2.5568, val loss 2.6801
# step 7550: train loss 2.5869, val loss 2.6883
# step 7560: train loss 2.5956, val loss 2.7268
# step 7570: train loss 2.6253, val loss 2.7585
# step 7580: train loss 2.5812, val loss 2.6955
# step 7590: train loss 2.5986, val loss 2.7163
# step 7600: train loss 2.5803, val loss 2.7306
# step 7610: train loss 2.6308, val loss 2.6943
# step 7620: train loss 2.6633, val loss 2.6185
# step 7630: train loss 2.5910, val loss 2.6610
# step 7640: train loss 2.6549, val loss 2.7479
# step 7650: train loss 2.6477, val loss 2.6251
# step 7660: train loss 2.5653, val loss 2.6532
# step 7670: train loss 2.6255, val loss 2.6910
# step 7680: train loss 2.6174, val loss 2.7355
# step 7690: train loss 2.5929, val loss 2.6679
# step 7700: train loss 2.6208, val loss 2.7113
# step 7710: train loss 2.5747, val loss 2.6716
# step 7720: train loss 2.5996, val loss 2.5873
# step 7730: train loss 2.6198, val loss 2.8004
# step 7740: train loss 2.5887, val loss 2.7064
# step 7750: train loss 2.6748, val loss 2.7525
# step 7760: train loss 2.6264, val loss 2.6502
# step 7770: train loss 2.6150, val loss 2.6839
# step 7780: train loss 2.5550, val loss 2.5777
# step 7790: train loss 2.6412, val loss 2.6449
# step 7800: train loss 2.5576, val loss 2.5720
# step 7810: train loss 2.5968, val loss 2.6248
# step 7820: train loss 2.5903, val loss 2.6992
# step 7830: train loss 2.5778, val loss 2.7016
# step 7840: train loss 2.5817, val loss 2.6729
# step 7850: train loss 2.6019, val loss 2.6832
# step 7860: train loss 2.5749, val loss 2.6738
# step 7870: train loss 2.5305, val loss 2.7053
# step 7880: train loss 2.5951, val loss 2.7160
# step 7890: train loss 2.6317, val loss 2.5853
# step 7900: train loss 2.5216, val loss 2.5586
# step 7910: train loss 2.5855, val loss 2.7114
# step 7920: train loss 2.4768, val loss 2.6697
# step 7930: train loss 2.6800, val loss 2.6519
# step 7940: train loss 2.5925, val loss 2.6065
# step 7950: train loss 2.5726, val loss 2.5337
# step 7960: train loss 2.6186, val loss 2.6957
# step 7970: train loss 2.5745, val loss 2.5862
# step 7980: train loss 2.5423, val loss 2.6198
# step 7990: train loss 2.5431, val loss 2.6516
# step 8000: train loss 2.6613, val loss 2.7331
# step 8010: train loss 2.6284, val loss 2.7024
# step 8020: train loss 2.5531, val loss 2.6940
# step 8030: train loss 2.5604, val loss 2.7088
# step 8040: train loss 2.5962, val loss 2.6657
# step 8050: train loss 2.6429, val loss 2.7301
# step 8060: train loss 2.5474, val loss 2.7685
# step 8070: train loss 2.6481, val loss 2.6126
# step 8080: train loss 2.5496, val loss 2.6072
# step 8090: train loss 2.6238, val loss 2.7297
# step 8100: train loss 2.6615, val loss 2.6237
# step 8110: train loss 2.5553, val loss 2.7333
# step 8120: train loss 2.6483, val loss 2.5852
# step 8130: train loss 2.5388, val loss 2.5707
# step 8140: train loss 2.6989, val loss 2.6769
# step 8150: train loss 2.6982, val loss 2.6941
# step 8160: train loss 2.5504, val loss 2.6963
# step 8170: train loss 2.5504, val loss 2.6489
# step 8180: train loss 2.6078, val loss 2.6150
# step 8190: train loss 2.6722, val loss 2.6337
# step 8200: train loss 2.5278, val loss 2.6063
# step 8210: train loss 2.6425, val loss 2.6942
# step 8220: train loss 2.5705, val loss 2.6638
# step 8230: train loss 2.5707, val loss 2.7191
# step 8240: train loss 2.4902, val loss 2.7573
# step 8250: train loss 2.5334, val loss 2.6381
# step 8260: train loss 2.5452, val loss 2.7458
# step 8270: train loss 2.5259, val loss 2.6211
# step 8280: train loss 2.6047, val loss 2.6502
# step 8290: train loss 2.5132, val loss 2.5657
# step 8300: train loss 2.5574, val loss 2.6053
# step 8310: train loss 2.5529, val loss 2.6759
# step 8320: train loss 2.5362, val loss 2.7020
# step 8330: train loss 2.6524, val loss 2.6328
# step 8340: train loss 2.5934, val loss 2.5648
# step 8350: train loss 2.5763, val loss 2.6489
# step 8360: train loss 2.5526, val loss 2.5143
# step 8370: train loss 2.6290, val loss 2.5634
# step 8380: train loss 2.5697, val loss 2.7562
# step 8390: train loss 2.5346, val loss 2.6464
# step 8400: train loss 2.6082, val loss 2.7338
# step 8410: train loss 2.5852, val loss 2.7633
# step 8420: train loss 2.6162, val loss 2.6934
# step 8430: train loss 2.5306, val loss 2.5994
# step 8440: train loss 2.5559, val loss 2.5412
# step 8450: train loss 2.5660, val loss 2.7305
# step 8460: train loss 2.6249, val loss 2.6842
# step 8470: train loss 2.6177, val loss 2.5769
# step 8480: train loss 2.5147, val loss 2.7085
# step 8490: train loss 2.5370, val loss 2.6028
# step 8500: train loss 2.5977, val loss 2.6224
# step 8510: train loss 2.5338, val loss 2.6117
# step 8520: train loss 2.5763, val loss 2.5143
# step 8530: train loss 2.5593, val loss 2.6145
# step 8540: train loss 2.5813, val loss 2.6253
# step 8550: train loss 2.5780, val loss 2.6061
# step 8560: train loss 2.5561, val loss 2.6280
# step 8570: train loss 2.5271, val loss 2.6616
# step 8580: train loss 2.6387, val loss 2.6622
# step 8590: train loss 2.4661, val loss 2.6132
# step 8600: train loss 2.5301, val loss 2.6876
# step 8610: train loss 2.6266, val loss 2.6281
# step 8620: train loss 2.5783, val loss 2.6204
# step 8630: train loss 2.6044, val loss 2.6480
# step 8640: train loss 2.5562, val loss 2.6481
# step 8650: train loss 2.5468, val loss 2.5369
# step 8660: train loss 2.5603, val loss 2.5644
# step 8670: train loss 2.4635, val loss 2.6498
# step 8680: train loss 2.4986, val loss 2.6791
# step 8690: train loss 2.5735, val loss 2.7028
# step 8700: train loss 2.5162, val loss 2.7077
# step 8710: train loss 2.5439, val loss 2.6181
# step 8720: train loss 2.6028, val loss 2.7068
# step 8730: train loss 2.5757, val loss 2.5921
# step 8740: train loss 2.4816, val loss 2.6124
# step 8750: train loss 2.5636, val loss 2.6513
# step 8760: train loss 2.6187, val loss 2.5812
# step 8770: train loss 2.5148, val loss 2.6044
# step 8780: train loss 2.5655, val loss 2.7169
# step 8790: train loss 2.6376, val loss 2.5690
# step 8800: train loss 2.5327, val loss 2.7342
# step 8810: train loss 2.5417, val loss 2.6258
# step 8820: train loss 2.5542, val loss 2.5922
# step 8830: train loss 2.5728, val loss 2.5935
# step 8840: train loss 2.5219, val loss 2.5361
# step 8850: train loss 2.4767, val loss 2.6272
# step 8860: train loss 2.4961, val loss 2.7412
# step 8870: train loss 2.5918, val loss 2.6215
# step 8880: train loss 2.5028, val loss 2.6389
# step 8890: train loss 2.5390, val loss 2.5803
# step 8900: train loss 2.5259, val loss 2.6905
# step 8910: train loss 2.5372, val loss 2.5835
# step 8920: train loss 2.5835, val loss 2.6252
# step 8930: train loss 2.5461, val loss 2.5959
# step 8940: train loss 2.5764, val loss 2.7853
# step 8950: train loss 2.5718, val loss 2.6518
# step 8960: train loss 2.6034, val loss 2.5480
# step 8970: train loss 2.5134, val loss 2.6041
# step 8980: train loss 2.5599, val loss 2.4761
# step 8990: train loss 2.5706, val loss 2.5267
# step 9000: train loss 2.5206, val loss 2.6008
# step 9010: train loss 2.5269, val loss 2.6041
# step 9020: train loss 2.5683, val loss 2.5401
# step 9030: train loss 2.5903, val loss 2.5848
# step 9040: train loss 2.4850, val loss 2.6112
# step 9050: train loss 2.5866, val loss 2.6336
# step 9060: train loss 2.5493, val loss 2.6785
# step 9070: train loss 2.6078, val loss 2.7041
# step 9080: train loss 2.5497, val loss 2.6986
# step 9090: train loss 2.5041, val loss 2.6822
# step 9100: train loss 2.5202, val loss 2.5548
# step 9110: train loss 2.4733, val loss 2.6858
# step 9120: train loss 2.5501, val loss 2.6844
# step 9130: train loss 2.5498, val loss 2.5952
# step 9140: train loss 2.5887, val loss 2.4872
# step 9150: train loss 2.5380, val loss 2.6063
# step 9160: train loss 2.4295, val loss 2.6271
# step 9170: train loss 2.5265, val loss 2.6595
# step 9180: train loss 2.4901, val loss 2.6535
# step 9190: train loss 2.5185, val loss 2.6114
# step 9200: train loss 2.6097, val loss 2.6218
# step 9210: train loss 2.5820, val loss 2.6176
# step 9220: train loss 2.5436, val loss 2.6743
# step 9230: train loss 2.6427, val loss 2.6175
# step 9240: train loss 2.5788, val loss 2.7460
# step 9250: train loss 2.4867, val loss 2.6103
# step 9260: train loss 2.5258, val loss 2.5636
# step 9270: train loss 2.5646, val loss 2.6170
# step 9280: train loss 2.5623, val loss 2.6056
# step 9290: train loss 2.5012, val loss 2.5207
# step 9300: train loss 2.5521, val loss 2.5691
# step 9310: train loss 2.5042, val loss 2.6089
# step 9320: train loss 2.5073, val loss 2.6256
# step 9330: train loss 2.5569, val loss 2.4817
# step 9340: train loss 2.5809, val loss 2.4794
# step 9350: train loss 2.5566, val loss 2.6581
# step 9360: train loss 2.5033, val loss 2.6096
# step 9370: train loss 2.5353, val loss 2.6356
# step 9380: train loss 2.4866, val loss 2.6485
# step 9390: train loss 2.5635, val loss 2.6354
# step 9400: train loss 2.5545, val loss 2.6506
# step 9410: train loss 2.4875, val loss 2.6231
# step 9420: train loss 2.5762, val loss 2.6249
# step 9430: train loss 2.5993, val loss 2.6685
# step 9440: train loss 2.4879, val loss 2.6890
# step 9450: train loss 2.4644, val loss 2.6077
# step 9460: train loss 2.5403, val loss 2.6027
# step 9470: train loss 2.5484, val loss 2.5966
# step 9480: train loss 2.5210, val loss 2.6287
# step 9490: train loss 2.5374, val loss 2.5710
# step 9500: train loss 2.4906, val loss 2.4966
# step 9510: train loss 2.5286, val loss 2.5448
# step 9520: train loss 2.5200, val loss 2.7573
# step 9530: train loss 2.4990, val loss 2.6444
# step 9540: train loss 2.5125, val loss 2.6753
# step 9550: train loss 2.4882, val loss 2.5493
# step 9560: train loss 2.5625, val loss 2.7857
# step 9570: train loss 2.5169, val loss 2.5881
# step 9580: train loss 2.4369, val loss 2.5979
# step 9590: train loss 2.5374, val loss 2.6337
# step 9600: train loss 2.5185, val loss 2.5678
# step 9610: train loss 2.5502, val loss 2.5509
# step 9620: train loss 2.5276, val loss 2.5354
# step 9630: train loss 2.4755, val loss 2.6221
# step 9640: train loss 2.4823, val loss 2.5694
# step 9650: train loss 2.4480, val loss 2.6149
# step 9660: train loss 2.4754, val loss 2.7479
# step 9670: train loss 2.4982, val loss 2.5338
# step 9680: train loss 2.5646, val loss 2.6040
# step 9690: train loss 2.5340, val loss 2.6596
# step 9700: train loss 2.4717, val loss 2.6333
# step 9710: train loss 2.4968, val loss 2.5832
# step 9720: train loss 2.5187, val loss 2.5943
# step 9730: train loss 2.4622, val loss 2.6026
# step 9740: train loss 2.4550, val loss 2.5361
# step 9750: train loss 2.4917, val loss 2.4789
# step 9760: train loss 2.4718, val loss 2.6108
# step 9770: train loss 2.4815, val loss 2.7158
# step 9780: train loss 2.4985, val loss 2.6117
# step 9790: train loss 2.5091, val loss 2.6288
# step 9800: train loss 2.5252, val loss 2.5916
# step 9810: train loss 2.5058, val loss 2.7033
# step 9820: train loss 2.5852, val loss 2.5473
# step 9830: train loss 2.5042, val loss 2.5924
# step 9840: train loss 2.4397, val loss 2.5725
# step 9850: train loss 2.5340, val loss 2.5692
# step 9860: train loss 2.4983, val loss 2.5843
# step 9870: train loss 2.5372, val loss 2.6087
# step 9880: train loss 2.5529, val loss 2.5556
# step 9890: train loss 2.5055, val loss 2.4964
# step 9900: train loss 2.5627, val loss 2.5936
# step 9910: train loss 2.4768, val loss 2.4999
# step 9920: train loss 2.4744, val loss 2.5916
# step 9930: train loss 2.5050, val loss 2.6473
# step 9940: train loss 2.4861, val loss 2.5924
# step 9950: train loss 2.4975, val loss 2.5483
# step 9960: train loss 2.4349, val loss 2.5115
# step 9970: train loss 2.4819, val loss 2.5744
# step 9980: train loss 2.4708, val loss 2.5527
# step 9990: train loss 2.5762, val loss 2.6490

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# VOhe: simarei Dilé lan lèbai qusaux.
# D»roie àEns cle l'esstjAyuie des,  A lèsut vitus le,
# J'e; garmm

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C*head_size)
# define the Query layer
query = nn.Linear(C*head_size)
# define the Value layer
value =  nn.Linear(C*head_size)
# apply each layer to the input
k =  key(x)  # (B, T, head_size)
q =  query(x)  # (B, T, head_size)
v =  value(x)  # (B, T, head_size)
# compute the normalize product between Q and K 
weights =  # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = 
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
#   Cell In[13], line 6
#     key =
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
