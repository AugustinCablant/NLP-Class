# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections
import numpy as np

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = counter.keys()
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
n = len(data)
train_prop = int(0.9 * n)
train_data, val_data = data[:train_prop], data[train_prop:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8  # taille maximale du contexte à considérer pour faire la prédiction du prochain caractère

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([36477])
# context is >'< target is >o<
# context is >'o< target is >r<
# context is >'or< target is >a<
# context is >'ora< target is >g<
# context is >'orag< target is >e<
# context is >'orage< target is > <
# context is >'orage < target is >e<
# context is >'orage e< target is >t<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4  
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    ix = torch.randint(low=0, high=len(data)-block_size-1, size=(batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([torch.as_tensor(data[i:i+block_size]).clone().detach() for i in ix])
    # y is the character after each starting position
    y = torch.stack([torch.as_tensor(data[i+1:i+block_size+1]).clone().detach() for i in ix])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.token_embedding_table(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)  #go on the forward function
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C) ; predictions of what comes next 
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
    
vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 5.081887722015381

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor([encode(['\n'])], dtype=torch.long)
idx_generated = m.generate(idx=prompt, max_new_tokens=100)
decoded_gen = decode(idx_generated[0].tolist())  
print(decoded_gen)
###
# Out:
# [3]
#
# X0xYÉH»pÉhÔR
# h« Cà::Lq·û;mYAXâÎsh((!:PlçLl.è2!laIÈn0:ÀX
# [5·Zeq)v6mùawwH3ù;_,Z0t.è4«1ÉMâ·Æô)j;!quùa-e

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10**4
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0457, val loss 5.0149
# step 10: train loss 5.0852, val loss 5.0614
# step 20: train loss 5.1357, val loss 5.0227
# step 30: train loss 5.1287, val loss 4.9576
# step 40: train loss 5.1183, val loss 5.0289
# step 50: train loss 5.0543, val loss 5.0186
# step 60: train loss 5.0792, val loss 4.9972
# step 70: train loss 5.0888, val loss 4.9307
# step 80: train loss 4.9998, val loss 4.9655
# step 90: train loss 5.0369, val loss 4.9522
# step 100: train loss 5.0660, val loss 4.9841
# step 110: train loss 5.0783, val loss 4.8929
# step 120: train loss 5.0328, val loss 4.9971
# step 130: train loss 5.0814, val loss 4.8887
# step 140: train loss 5.0126, val loss 4.9415
# step 150: train loss 4.9602, val loss 4.9161
# step 160: train loss 4.9400, val loss 4.9269
# step 170: train loss 4.9689, val loss 4.8465
# step 180: train loss 4.8751, val loss 4.8477
# step 190: train loss 4.9097, val loss 4.8555
# step 200: train loss 4.8922, val loss 4.9092
# step 210: train loss 4.9177, val loss 4.8778
# step 220: train loss 4.9017, val loss 4.8738
# step 230: train loss 4.9261, val loss 4.8314
# step 240: train loss 4.9390, val loss 4.7943
# step 250: train loss 4.8831, val loss 4.8235
# step 260: train loss 4.8465, val loss 4.8358
# step 270: train loss 4.9003, val loss 4.8341
# step 280: train loss 4.9025, val loss 4.7520
# step 290: train loss 4.8349, val loss 4.8127
# step 300: train loss 4.8885, val loss 4.8260
# step 310: train loss 4.7843, val loss 4.8169
# step 320: train loss 4.8473, val loss 4.8129
# step 330: train loss 4.7808, val loss 4.7838
# step 340: train loss 4.8113, val loss 4.7763
# step 350: train loss 4.8103, val loss 4.7837
# step 360: train loss 4.8134, val loss 4.8023
# step 370: train loss 4.7399, val loss 4.7471
# step 380: train loss 4.7465, val loss 4.6944
# step 390: train loss 4.7727, val loss 4.7298
# step 400: train loss 4.7913, val loss 4.7654
# step 410: train loss 4.7402, val loss 4.7427
# step 420: train loss 4.7846, val loss 4.6939
# step 430: train loss 4.7977, val loss 4.7102
# step 440: train loss 4.7588, val loss 4.6983
# step 450: train loss 4.7106, val loss 4.7446
# step 460: train loss 4.7149, val loss 4.6310
# step 470: train loss 4.6737, val loss 4.6945
# step 480: train loss 4.7038, val loss 4.6420
# step 490: train loss 4.7270, val loss 4.6182
# step 500: train loss 4.6677, val loss 4.6772
# step 510: train loss 4.6711, val loss 4.5946
# step 520: train loss 4.7116, val loss 4.6408
# step 530: train loss 4.6855, val loss 4.6251
# step 540: train loss 4.6089, val loss 4.5460
# step 550: train loss 4.6772, val loss 4.6857
# step 560: train loss 4.6693, val loss 4.5683
# step 570: train loss 4.6919, val loss 4.5583
# step 580: train loss 4.6393, val loss 4.5220
# step 590: train loss 4.6407, val loss 4.5379
# step 600: train loss 4.6397, val loss 4.5719
# step 610: train loss 4.6010, val loss 4.6113
# step 620: train loss 4.5652, val loss 4.5627
# step 630: train loss 4.5511, val loss 4.5375
# step 640: train loss 4.5681, val loss 4.4999
# step 650: train loss 4.6279, val loss 4.5627
# step 660: train loss 4.5949, val loss 4.5193
# step 670: train loss 4.5342, val loss 4.5528
# step 680: train loss 4.5261, val loss 4.4872
# step 690: train loss 4.5094, val loss 4.4702
# step 700: train loss 4.5519, val loss 4.4408
# step 710: train loss 4.5364, val loss 4.4319
# step 720: train loss 4.4845, val loss 4.4873
# step 730: train loss 4.4477, val loss 4.4878
# step 740: train loss 4.4835, val loss 4.4477
# step 750: train loss 4.4954, val loss 4.4582
# step 760: train loss 4.4879, val loss 4.4819
# step 770: train loss 4.4683, val loss 4.4603
# step 780: train loss 4.4486, val loss 4.3554
# step 790: train loss 4.4879, val loss 4.4371
# step 800: train loss 4.4609, val loss 4.3963
# step 810: train loss 4.4520, val loss 4.3779
# step 820: train loss 4.4166, val loss 4.4112
# step 830: train loss 4.4504, val loss 4.4912
# step 840: train loss 4.4373, val loss 4.4444
# step 850: train loss 4.4082, val loss 4.4398
# step 860: train loss 4.4090, val loss 4.2897
# step 870: train loss 4.3313, val loss 4.3333
# step 880: train loss 4.3604, val loss 4.4074
# step 890: train loss 4.3753, val loss 4.3100
# step 900: train loss 4.3726, val loss 4.3303
# step 910: train loss 4.3923, val loss 4.2564
# step 920: train loss 4.4116, val loss 4.3563
# step 930: train loss 4.3879, val loss 4.3520
# step 940: train loss 4.3662, val loss 4.2756
# step 950: train loss 4.3874, val loss 4.3221
# step 960: train loss 4.3315, val loss 4.3104
# step 970: train loss 4.3647, val loss 4.3173
# step 980: train loss 4.3177, val loss 4.2854
# step 990: train loss 4.3020, val loss 4.2609
# step 1000: train loss 4.2676, val loss 4.3418
# step 1010: train loss 4.2564, val loss 4.1918
# step 1020: train loss 4.2864, val loss 4.2983
# step 1030: train loss 4.2488, val loss 4.2009
# step 1040: train loss 4.2709, val loss 4.1857
# step 1050: train loss 4.1696, val loss 4.2156
# step 1060: train loss 4.2609, val loss 4.2760
# step 1070: train loss 4.2858, val loss 4.1441
# step 1080: train loss 4.2294, val loss 4.2482
# step 1090: train loss 4.2255, val loss 4.2482
# step 1100: train loss 4.2716, val loss 4.2170
# step 1110: train loss 4.2027, val loss 4.1941
# step 1120: train loss 4.2431, val loss 4.1435
# step 1130: train loss 4.1722, val loss 4.1742
# step 1140: train loss 4.2567, val loss 4.1358
# step 1150: train loss 4.1959, val loss 4.1866
# step 1160: train loss 4.1531, val loss 4.1219
# step 1170: train loss 4.2218, val loss 4.1720
# step 1180: train loss 4.1954, val loss 4.1866
# step 1190: train loss 4.2222, val loss 4.1407
# step 1200: train loss 4.2091, val loss 4.2490
# step 1210: train loss 4.1742, val loss 4.1120
# step 1220: train loss 4.1141, val loss 4.1359
# step 1230: train loss 4.1992, val loss 4.0760
# step 1240: train loss 4.1629, val loss 4.1497
# step 1250: train loss 4.1344, val loss 4.0735
# step 1260: train loss 4.0922, val loss 4.0493
# step 1270: train loss 4.1238, val loss 4.1208
# step 1280: train loss 4.1490, val loss 4.1292
# step 1290: train loss 4.0646, val loss 4.0676
# step 1300: train loss 4.1451, val loss 4.0581
# step 1310: train loss 4.0373, val loss 4.1097
# step 1320: train loss 4.0772, val loss 4.0255
# step 1330: train loss 4.0067, val loss 4.0279
# step 1340: train loss 4.1079, val loss 4.0304
# step 1350: train loss 4.0484, val loss 3.9992
# step 1360: train loss 4.0944, val loss 4.0501
# step 1370: train loss 4.0293, val loss 4.0532
# step 1380: train loss 4.0393, val loss 3.9163
# step 1390: train loss 3.9747, val loss 3.9435
# step 1400: train loss 4.0275, val loss 4.0023
# step 1410: train loss 4.0237, val loss 4.0235
# step 1420: train loss 4.0112, val loss 3.9599
# step 1430: train loss 4.0134, val loss 3.9692
# step 1440: train loss 4.0159, val loss 3.9598
# step 1450: train loss 3.9739, val loss 3.9767
# step 1460: train loss 4.0247, val loss 3.9762
# step 1470: train loss 4.0142, val loss 4.0589
# step 1480: train loss 4.0004, val loss 3.9875
# step 1490: train loss 3.9688, val loss 3.9274
# step 1500: train loss 4.0499, val loss 3.9882
# step 1510: train loss 4.0301, val loss 4.0443
# step 1520: train loss 4.0031, val loss 3.9673
# step 1530: train loss 3.9631, val loss 3.9033
# step 1540: train loss 3.9252, val loss 3.9638
# step 1550: train loss 3.9567, val loss 3.9571
# step 1560: train loss 3.9698, val loss 3.8993
# step 1570: train loss 3.9216, val loss 3.8702
# step 1580: train loss 3.9704, val loss 4.0325
# step 1590: train loss 3.9317, val loss 3.9137
# step 1600: train loss 3.8973, val loss 3.9261
# step 1610: train loss 3.8841, val loss 3.8990
# step 1620: train loss 3.8629, val loss 3.8241
# step 1630: train loss 3.8870, val loss 3.8587
# step 1640: train loss 3.9022, val loss 3.8522
# step 1650: train loss 3.8855, val loss 3.9176
# step 1660: train loss 3.9176, val loss 3.8920
# step 1670: train loss 3.8765, val loss 3.7943
# step 1680: train loss 3.9042, val loss 3.8255
# step 1690: train loss 3.7966, val loss 3.9155
# step 1700: train loss 3.8489, val loss 3.9131
# step 1710: train loss 3.8918, val loss 3.8025
# step 1720: train loss 3.8453, val loss 3.8161
# step 1730: train loss 3.8122, val loss 3.8185
# step 1740: train loss 3.9640, val loss 3.7787
# step 1750: train loss 3.7841, val loss 3.8019
# step 1760: train loss 3.8811, val loss 3.8345
# step 1770: train loss 3.7534, val loss 3.7556
# step 1780: train loss 3.7789, val loss 3.7674
# step 1790: train loss 3.7625, val loss 3.7742
# step 1800: train loss 3.7988, val loss 3.8179
# step 1810: train loss 3.7666, val loss 3.7626
# step 1820: train loss 3.7985, val loss 3.8187
# step 1830: train loss 3.8250, val loss 3.7561
# step 1840: train loss 3.7483, val loss 3.7617
# step 1850: train loss 3.7513, val loss 3.7748
# step 1860: train loss 3.8058, val loss 3.8204
# step 1870: train loss 3.6998, val loss 3.7244
# step 1880: train loss 3.7582, val loss 3.7336
# step 1890: train loss 3.7755, val loss 3.7345
# step 1900: train loss 3.8376, val loss 3.7907
# step 1910: train loss 3.7561, val loss 3.7154
# step 1920: train loss 3.7510, val loss 3.7759
# step 1930: train loss 3.7601, val loss 3.7633
# step 1940: train loss 3.7745, val loss 3.8387
# step 1950: train loss 3.7708, val loss 3.6782
# step 1960: train loss 3.7511, val loss 3.7853
# step 1970: train loss 3.7589, val loss 3.6507
# step 1980: train loss 3.7541, val loss 3.6709
# step 1990: train loss 3.6935, val loss 3.7300
# step 2000: train loss 3.6680, val loss 3.7254
# step 2010: train loss 3.7266, val loss 3.7330
# step 2020: train loss 3.7098, val loss 3.6662
# step 2030: train loss 3.6777, val loss 3.5885
# step 2040: train loss 3.7071, val loss 3.6995
# step 2050: train loss 3.6970, val loss 3.6976
# step 2060: train loss 3.6354, val loss 3.7078
# step 2070: train loss 3.6123, val loss 3.6744
# step 2080: train loss 3.6518, val loss 3.6340
# step 2090: train loss 3.6472, val loss 3.6070
# step 2100: train loss 3.6820, val loss 3.6813
# step 2110: train loss 3.6702, val loss 3.7014
# step 2120: train loss 3.6183, val loss 3.6701
# step 2130: train loss 3.6669, val loss 3.6607
# step 2140: train loss 3.6724, val loss 3.6507
# step 2150: train loss 3.6326, val loss 3.6968
# step 2160: train loss 3.5768, val loss 3.5910
# step 2170: train loss 3.6141, val loss 3.6552
# step 2180: train loss 3.6313, val loss 3.6620
# step 2190: train loss 3.5886, val loss 3.6318
# step 2200: train loss 3.6171, val loss 3.6176
# step 2210: train loss 3.5993, val loss 3.6721
# step 2220: train loss 3.5460, val loss 3.5387
# step 2230: train loss 3.6366, val loss 3.6000
# step 2240: train loss 3.6850, val loss 3.5757
# step 2250: train loss 3.6511, val loss 3.6465
# step 2260: train loss 3.5747, val loss 3.6002
# step 2270: train loss 3.5362, val loss 3.5802
# step 2280: train loss 3.6089, val loss 3.4775
# step 2290: train loss 3.5328, val loss 3.5650
# step 2300: train loss 3.5216, val loss 3.5627
# step 2310: train loss 3.5650, val loss 3.5287
# step 2320: train loss 3.5654, val loss 3.4743
# step 2330: train loss 3.6250, val loss 3.4848
# step 2340: train loss 3.5818, val loss 3.5214
# step 2350: train loss 3.5611, val loss 3.5055
# step 2360: train loss 3.4596, val loss 3.6075
# step 2370: train loss 3.4457, val loss 3.4766
# step 2380: train loss 3.4774, val loss 3.4936
# step 2390: train loss 3.5130, val loss 3.5005
# step 2400: train loss 3.5867, val loss 3.5440
# step 2410: train loss 3.5400, val loss 3.5561
# step 2420: train loss 3.4625, val loss 3.5141
# step 2430: train loss 3.4663, val loss 3.4969
# step 2440: train loss 3.4439, val loss 3.4771
# step 2450: train loss 3.5108, val loss 3.4976
# step 2460: train loss 3.4564, val loss 3.5200
# step 2470: train loss 3.5260, val loss 3.5000
# step 2480: train loss 3.4961, val loss 3.5089
# step 2490: train loss 3.5063, val loss 3.4978
# step 2500: train loss 3.4911, val loss 3.4958
# step 2510: train loss 3.4382, val loss 3.4966
# step 2520: train loss 3.4926, val loss 3.4756
# step 2530: train loss 3.4745, val loss 3.4337
# step 2540: train loss 3.5037, val loss 3.5485
# step 2550: train loss 3.4367, val loss 3.5582
# step 2560: train loss 3.4299, val loss 3.4472
# step 2570: train loss 3.4293, val loss 3.4271
# step 2580: train loss 3.4890, val loss 3.4372
# step 2590: train loss 3.4154, val loss 3.5006
# step 2600: train loss 3.3941, val loss 3.4399
# step 2610: train loss 3.4618, val loss 3.4035
# step 2620: train loss 3.4638, val loss 3.5157
# step 2630: train loss 3.4154, val loss 3.3608
# step 2640: train loss 3.3744, val loss 3.2928
# step 2650: train loss 3.3965, val loss 3.4128
# step 2660: train loss 3.4559, val loss 3.3984
# step 2670: train loss 3.3710, val loss 3.4278
# step 2680: train loss 3.4237, val loss 3.3023
# step 2690: train loss 3.3958, val loss 3.4455
# step 2700: train loss 3.3653, val loss 3.4069
# step 2710: train loss 3.3798, val loss 3.3566
# step 2720: train loss 3.3794, val loss 3.4059
# step 2730: train loss 3.3983, val loss 3.3699
# step 2740: train loss 3.4103, val loss 3.3682
# step 2750: train loss 3.3382, val loss 3.3821
# step 2760: train loss 3.3325, val loss 3.3955
# step 2770: train loss 3.3344, val loss 3.4601
# step 2780: train loss 3.3248, val loss 3.4026
# step 2790: train loss 3.3474, val loss 3.3577
# step 2800: train loss 3.4900, val loss 3.2468
# step 2810: train loss 3.3736, val loss 3.4100
# step 2820: train loss 3.3998, val loss 3.3875
# step 2830: train loss 3.3261, val loss 3.4135
# step 2840: train loss 3.2538, val loss 3.4275
# step 2850: train loss 3.3480, val loss 3.3417
# step 2860: train loss 3.3321, val loss 3.2822
# step 2870: train loss 3.3023, val loss 3.3112
# step 2880: train loss 3.3677, val loss 3.3591
# step 2890: train loss 3.3316, val loss 3.2371
# step 2900: train loss 3.2583, val loss 3.2964
# step 2910: train loss 3.2923, val loss 3.3164
# step 2920: train loss 3.2566, val loss 3.3201
# step 2930: train loss 3.3279, val loss 3.3463
# step 2940: train loss 3.3201, val loss 3.2630
# step 2950: train loss 3.2885, val loss 3.3250
# step 2960: train loss 3.2839, val loss 3.4707
# step 2970: train loss 3.2792, val loss 3.3651
# step 2980: train loss 3.3090, val loss 3.2738
# step 2990: train loss 3.3202, val loss 3.3246
# step 3000: train loss 3.2970, val loss 3.2493
# step 3010: train loss 3.3129, val loss 3.3596
# step 3020: train loss 3.3135, val loss 3.3282
# step 3030: train loss 3.3058, val loss 3.2479
# step 3040: train loss 3.2615, val loss 3.1894
# step 3050: train loss 3.2689, val loss 3.2921
# step 3060: train loss 3.3213, val loss 3.2294
# step 3070: train loss 3.2751, val loss 3.3123
# step 3080: train loss 3.2023, val loss 3.2012
# step 3090: train loss 3.3088, val loss 3.3493
# step 3100: train loss 3.3158, val loss 3.4039
# step 3110: train loss 3.2235, val loss 3.2201
# step 3120: train loss 3.3077, val loss 3.2754
# step 3130: train loss 3.3041, val loss 3.2987
# step 3140: train loss 3.2666, val loss 3.3367
# step 3150: train loss 3.2172, val loss 3.2343
# step 3160: train loss 3.2037, val loss 3.3366
# step 3170: train loss 3.2957, val loss 3.2891
# step 3180: train loss 3.2723, val loss 3.3047
# step 3190: train loss 3.2073, val loss 3.2364
# step 3200: train loss 3.2395, val loss 3.2962
# step 3210: train loss 3.1701, val loss 3.1530
# step 3220: train loss 3.3227, val loss 3.3377
# step 3230: train loss 3.1565, val loss 3.2987
# step 3240: train loss 3.2359, val loss 3.2121
# step 3250: train loss 3.2176, val loss 3.2639
# step 3260: train loss 3.2684, val loss 3.2832
# step 3270: train loss 3.1412, val loss 3.3732
# step 3280: train loss 3.2098, val loss 3.1732
# step 3290: train loss 3.2795, val loss 3.2444
# step 3300: train loss 3.1943, val loss 3.1558
# step 3310: train loss 3.1424, val loss 3.1895
# step 3320: train loss 3.1976, val loss 3.2030
# step 3330: train loss 3.2548, val loss 3.3062
# step 3340: train loss 3.2439, val loss 3.1796
# step 3350: train loss 3.2063, val loss 3.1056
# step 3360: train loss 3.0905, val loss 3.2125
# step 3370: train loss 3.1827, val loss 3.3310
# step 3380: train loss 3.1802, val loss 3.1536
# step 3390: train loss 3.0710, val loss 3.1468
# step 3400: train loss 3.1699, val loss 3.1639
# step 3410: train loss 3.1269, val loss 3.2274
# step 3420: train loss 3.1902, val loss 3.1827
# step 3430: train loss 3.0945, val loss 3.2283
# step 3440: train loss 3.1943, val loss 3.1234
# step 3450: train loss 3.2700, val loss 3.2122
# step 3460: train loss 3.1173, val loss 3.1687
# step 3470: train loss 3.1712, val loss 3.1970
# step 3480: train loss 3.1398, val loss 3.1516
# step 3490: train loss 3.2516, val loss 3.1453
# step 3500: train loss 3.0989, val loss 3.1629
# step 3510: train loss 3.1501, val loss 3.2424
# step 3520: train loss 3.0950, val loss 3.0897
# step 3530: train loss 3.1398, val loss 3.1558
# step 3540: train loss 3.1984, val loss 3.2406
# step 3550: train loss 3.0886, val loss 3.2188
# step 3560: train loss 3.1250, val loss 3.1322
# step 3570: train loss 3.1610, val loss 3.1373
# step 3580: train loss 3.1011, val loss 3.1373
# step 3590: train loss 3.0781, val loss 3.1751
# step 3600: train loss 3.1195, val loss 3.1661
# step 3610: train loss 3.1141, val loss 3.1260
# step 3620: train loss 3.1453, val loss 3.2046
# step 3630: train loss 3.1463, val loss 3.1363
# step 3640: train loss 3.1168, val loss 3.1161
# step 3650: train loss 3.1307, val loss 3.1672
# step 3660: train loss 3.1469, val loss 3.2138
# step 3670: train loss 3.1052, val loss 3.1232
# step 3680: train loss 3.0666, val loss 3.2061
# step 3690: train loss 3.0746, val loss 3.1664
# step 3700: train loss 3.1116, val loss 3.0879
# step 3710: train loss 3.1471, val loss 3.0766
# step 3720: train loss 3.0432, val loss 3.0185
# step 3730: train loss 3.0716, val loss 3.0453
# step 3740: train loss 3.1116, val loss 3.1384
# step 3750: train loss 3.0409, val loss 3.0220
# step 3760: train loss 3.0606, val loss 3.2391
# step 3770: train loss 3.1268, val loss 3.1290
# step 3780: train loss 3.0450, val loss 3.0286
# step 3790: train loss 3.0836, val loss 3.1170
# step 3800: train loss 3.0964, val loss 3.0843
# step 3810: train loss 3.0623, val loss 3.1987
# step 3820: train loss 3.0151, val loss 3.2548
# step 3830: train loss 2.9873, val loss 3.1075
# step 3840: train loss 3.0748, val loss 3.0849
# step 3850: train loss 3.0775, val loss 3.1086
# step 3860: train loss 3.0354, val loss 3.0325
# step 3870: train loss 3.0837, val loss 3.0971
# step 3880: train loss 2.9415, val loss 3.1653
# step 3890: train loss 3.1436, val loss 3.0538
# step 3900: train loss 3.0595, val loss 3.0030
# step 3910: train loss 3.0657, val loss 3.0450
# step 3920: train loss 3.0706, val loss 2.9376
# step 3930: train loss 2.9916, val loss 3.0441
# step 3940: train loss 3.0401, val loss 3.0375
# step 3950: train loss 3.0794, val loss 3.0662
# step 3960: train loss 3.0891, val loss 3.0620
# step 3970: train loss 3.0613, val loss 3.0588
# step 3980: train loss 3.1056, val loss 3.0538
# step 3990: train loss 2.9899, val loss 2.9915
# step 4000: train loss 2.9771, val loss 3.0391
# step 4010: train loss 2.9153, val loss 3.0546
# step 4020: train loss 2.9506, val loss 3.0386
# step 4030: train loss 2.9691, val loss 2.9747
# step 4040: train loss 2.9978, val loss 3.1085
# step 4050: train loss 2.9975, val loss 3.1048
# step 4060: train loss 2.9826, val loss 3.0741
# step 4070: train loss 2.9731, val loss 3.0196
# step 4080: train loss 3.0086, val loss 3.0129
# step 4090: train loss 3.0259, val loss 3.0707
# step 4100: train loss 2.9621, val loss 2.9753
# step 4110: train loss 2.9878, val loss 3.0178
# step 4120: train loss 3.0091, val loss 2.9969
# step 4130: train loss 3.0322, val loss 2.9282
# step 4140: train loss 3.0174, val loss 3.0240
# step 4150: train loss 2.9410, val loss 2.9175
# step 4160: train loss 2.9680, val loss 2.9470
# step 4170: train loss 2.9828, val loss 3.0671
# step 4180: train loss 2.9932, val loss 3.0053
# step 4190: train loss 3.0052, val loss 2.9249
# step 4200: train loss 3.0234, val loss 2.9669
# step 4210: train loss 2.9643, val loss 3.0558
# step 4220: train loss 2.8866, val loss 2.9272
# step 4230: train loss 2.9333, val loss 3.0560
# step 4240: train loss 2.9311, val loss 2.9268
# step 4250: train loss 2.9690, val loss 3.0784
# step 4260: train loss 2.9421, val loss 3.0521
# step 4270: train loss 2.9394, val loss 3.0906
# step 4280: train loss 3.0304, val loss 3.0134
# step 4290: train loss 2.9527, val loss 3.0335
# step 4300: train loss 2.9345, val loss 3.0164
# step 4310: train loss 2.8732, val loss 3.0220
# step 4320: train loss 3.0081, val loss 3.0156
# step 4330: train loss 2.9700, val loss 2.9641
# step 4340: train loss 2.9748, val loss 2.9584
# step 4350: train loss 3.0064, val loss 2.9467
# step 4360: train loss 2.9411, val loss 2.9808
# step 4370: train loss 2.9474, val loss 2.9370
# step 4380: train loss 2.9249, val loss 2.9785
# step 4390: train loss 2.9389, val loss 2.9520
# step 4400: train loss 2.9168, val loss 2.9581
# step 4410: train loss 2.9731, val loss 3.0457
# step 4420: train loss 2.8830, val loss 2.9768
# step 4430: train loss 2.9120, val loss 2.9656
# step 4440: train loss 2.9479, val loss 2.8914
# step 4450: train loss 2.9698, val loss 2.8355
# step 4460: train loss 2.9849, val loss 2.9276
# step 4470: train loss 3.0042, val loss 2.9749
# step 4480: train loss 2.8959, val loss 3.0637
# step 4490: train loss 2.9892, val loss 2.9999
# step 4500: train loss 2.9055, val loss 2.9619
# step 4510: train loss 2.8639, val loss 2.9931
# step 4520: train loss 2.9244, val loss 3.0219
# step 4530: train loss 2.8913, val loss 2.9691
# step 4540: train loss 2.8866, val loss 3.0352
# step 4550: train loss 2.9109, val loss 2.9727
# step 4560: train loss 2.9860, val loss 2.9988
# step 4570: train loss 2.8992, val loss 3.0191
# step 4580: train loss 2.9619, val loss 2.9723
# step 4590: train loss 2.8654, val loss 2.9093
# step 4600: train loss 2.8866, val loss 2.9409
# step 4610: train loss 2.8430, val loss 2.8932
# step 4620: train loss 2.9398, val loss 2.9266
# step 4630: train loss 2.8424, val loss 2.8782
# step 4640: train loss 2.8770, val loss 2.8895
# step 4650: train loss 2.9172, val loss 2.8807
# step 4660: train loss 2.9291, val loss 2.9078
# step 4670: train loss 2.8949, val loss 2.9336
# step 4680: train loss 2.8854, val loss 2.8435
# step 4690: train loss 2.8825, val loss 3.0251
# step 4700: train loss 2.9785, val loss 2.9397
# step 4710: train loss 2.8779, val loss 2.9393
# step 4720: train loss 2.8185, val loss 2.8951
# step 4730: train loss 2.8390, val loss 2.9054
# step 4740: train loss 2.8859, val loss 2.9523
# step 4750: train loss 2.9186, val loss 2.9606
# step 4760: train loss 2.8484, val loss 3.0129
# step 4770: train loss 2.8689, val loss 2.8825
# step 4780: train loss 2.8061, val loss 2.9665
# step 4790: train loss 2.7780, val loss 2.7809
# step 4800: train loss 2.9098, val loss 2.8136
# step 4810: train loss 2.8829, val loss 2.9025
# step 4820: train loss 2.8765, val loss 2.8726
# step 4830: train loss 2.8723, val loss 2.9259
# step 4840: train loss 2.8368, val loss 2.8958
# step 4850: train loss 2.9168, val loss 2.9138
# step 4860: train loss 2.7223, val loss 2.8169
# step 4870: train loss 2.8895, val loss 2.8130
# step 4880: train loss 2.9192, val loss 2.8445
# step 4890: train loss 2.8411, val loss 2.8683
# step 4900: train loss 2.8898, val loss 2.9129
# step 4910: train loss 2.8871, val loss 2.9107
# step 4920: train loss 2.8472, val loss 2.9269
# step 4930: train loss 2.8665, val loss 2.8166
# step 4940: train loss 2.8076, val loss 2.8652
# step 4950: train loss 2.8115, val loss 2.9491
# step 4960: train loss 2.8572, val loss 2.8916
# step 4970: train loss 2.8751, val loss 2.9963
# step 4980: train loss 2.8242, val loss 2.9018
# step 4990: train loss 2.7499, val loss 2.8606
# step 5000: train loss 2.9103, val loss 2.9753
# step 5010: train loss 2.8661, val loss 2.8876
# step 5020: train loss 2.7846, val loss 2.7923
# step 5030: train loss 2.8670, val loss 2.9418
# step 5040: train loss 2.8657, val loss 2.9548
# step 5050: train loss 2.8330, val loss 2.8702
# step 5060: train loss 2.8565, val loss 2.7797
# step 5070: train loss 2.8717, val loss 2.9138
# step 5080: train loss 2.8566, val loss 2.7832
# step 5090: train loss 2.9014, val loss 2.9178
# step 5100: train loss 2.7700, val loss 2.8949
# step 5110: train loss 2.8865, val loss 2.9723
# step 5120: train loss 2.8879, val loss 2.8796
# step 5130: train loss 2.8650, val loss 2.8515
# step 5140: train loss 2.8231, val loss 2.8378
# step 5150: train loss 2.8980, val loss 2.8447
# step 5160: train loss 2.7967, val loss 2.8952
# step 5170: train loss 2.8166, val loss 2.8501
# step 5180: train loss 2.8898, val loss 2.8545
# step 5190: train loss 2.7566, val loss 2.8871
# step 5200: train loss 2.8049, val loss 2.7797
# step 5210: train loss 2.8597, val loss 2.8745
# step 5220: train loss 2.7666, val loss 2.8528
# step 5230: train loss 2.8213, val loss 2.8541
# step 5240: train loss 2.8091, val loss 2.8711
# step 5250: train loss 2.7943, val loss 2.9297
# step 5260: train loss 2.7769, val loss 2.8557
# step 5270: train loss 2.8124, val loss 2.9130
# step 5280: train loss 2.7901, val loss 2.7451
# step 5290: train loss 2.8524, val loss 2.8876
# step 5300: train loss 2.7769, val loss 2.7578
# step 5310: train loss 2.8618, val loss 2.8150
# step 5320: train loss 2.7824, val loss 2.8388
# step 5330: train loss 2.7550, val loss 2.7213
# step 5340: train loss 2.7912, val loss 2.8141
# step 5350: train loss 2.7309, val loss 2.8256
# step 5360: train loss 2.8163, val loss 2.8494
# step 5370: train loss 2.7676, val loss 2.9100
# step 5380: train loss 2.8367, val loss 2.8579
# step 5390: train loss 2.6985, val loss 2.7857
# step 5400: train loss 2.8273, val loss 2.8662
# step 5410: train loss 2.8603, val loss 2.8343
# step 5420: train loss 2.7770, val loss 2.7783
# step 5430: train loss 2.7644, val loss 2.8278
# step 5440: train loss 2.7739, val loss 2.8587
# step 5450: train loss 2.8358, val loss 2.8606
# step 5460: train loss 2.7686, val loss 2.8866
# step 5470: train loss 2.7173, val loss 2.8095
# step 5480: train loss 2.6579, val loss 2.8109
# step 5490: train loss 2.7792, val loss 2.8491
# step 5500: train loss 2.7539, val loss 2.7859
# step 5510: train loss 2.7622, val loss 2.7787
# step 5520: train loss 2.7353, val loss 2.7719
# step 5530: train loss 2.7337, val loss 2.7840
# step 5540: train loss 2.8282, val loss 2.8674
# step 5550: train loss 2.7828, val loss 2.8271
# step 5560: train loss 2.7672, val loss 2.7545
# step 5570: train loss 2.7840, val loss 2.8687
# step 5580: train loss 2.7574, val loss 2.8570
# step 5590: train loss 2.7583, val loss 2.8897
# step 5600: train loss 2.7494, val loss 3.0015
# step 5610: train loss 2.6777, val loss 2.8404
# step 5620: train loss 2.8210, val loss 2.7547
# step 5630: train loss 2.7126, val loss 2.7720
# step 5640: train loss 2.8380, val loss 2.8750
# step 5650: train loss 2.7102, val loss 2.7529
# step 5660: train loss 2.7781, val loss 2.7747
# step 5670: train loss 2.7229, val loss 2.8122
# step 5680: train loss 2.7848, val loss 2.8536
# step 5690: train loss 2.8157, val loss 2.7802
# step 5700: train loss 2.7609, val loss 2.8048
# step 5710: train loss 2.7529, val loss 2.8796
# step 5720: train loss 2.7583, val loss 2.7852
# step 5730: train loss 2.7270, val loss 2.7875
# step 5740: train loss 2.6859, val loss 2.8258
# step 5750: train loss 2.7569, val loss 2.6864
# step 5760: train loss 2.7434, val loss 2.8047
# step 5770: train loss 2.7571, val loss 2.8297
# step 5780: train loss 2.6777, val loss 2.7748
# step 5790: train loss 2.7055, val loss 2.7560
# step 5800: train loss 2.7743, val loss 2.6796
# step 5810: train loss 2.7740, val loss 2.7737
# step 5820: train loss 2.7051, val loss 2.7904
# step 5830: train loss 2.7724, val loss 2.8445
# step 5840: train loss 2.7716, val loss 2.8088
# step 5850: train loss 2.6988, val loss 2.6828
# step 5860: train loss 2.7656, val loss 2.8763
# step 5870: train loss 2.7709, val loss 2.7421
# step 5880: train loss 2.8251, val loss 2.7633
# step 5890: train loss 2.7201, val loss 2.7020
# step 5900: train loss 2.7716, val loss 2.7241
# step 5910: train loss 2.6820, val loss 2.8317
# step 5920: train loss 2.6927, val loss 2.6856
# step 5930: train loss 2.6813, val loss 2.7794
# step 5940: train loss 2.7537, val loss 2.7589
# step 5950: train loss 2.6744, val loss 2.7816
# step 5960: train loss 2.7124, val loss 2.7524
# step 5970: train loss 2.7876, val loss 2.7802
# step 5980: train loss 2.7090, val loss 2.7382
# step 5990: train loss 2.7086, val loss 2.7245
# step 6000: train loss 2.7302, val loss 2.7327
# step 6010: train loss 2.6886, val loss 2.7316
# step 6020: train loss 2.7376, val loss 2.8310
# step 6030: train loss 2.7364, val loss 2.7859
# step 6040: train loss 2.7413, val loss 2.7656
# step 6050: train loss 2.7912, val loss 2.7668
# step 6060: train loss 2.6651, val loss 2.7581
# step 6070: train loss 2.8335, val loss 2.6993
# step 6080: train loss 2.7231, val loss 2.6889
# step 6090: train loss 2.7171, val loss 2.6942
# step 6100: train loss 2.7515, val loss 2.6637
# step 6110: train loss 2.7159, val loss 2.7416
# step 6120: train loss 2.6519, val loss 2.7371
# step 6130: train loss 2.7194, val loss 2.7638
# step 6140: train loss 2.7451, val loss 2.8357
# step 6150: train loss 2.6681, val loss 2.8408
# step 6160: train loss 2.6742, val loss 2.8981
# step 6170: train loss 2.7525, val loss 2.7378
# step 6180: train loss 2.6760, val loss 2.7624
# step 6190: train loss 2.7062, val loss 2.6706
# step 6200: train loss 2.7347, val loss 2.7453
# step 6210: train loss 2.6522, val loss 2.8159
# step 6220: train loss 2.6159, val loss 2.7215
# step 6230: train loss 2.7208, val loss 2.8065
# step 6240: train loss 2.5961, val loss 2.7303
# step 6250: train loss 2.6913, val loss 2.7855
# step 6260: train loss 2.6387, val loss 2.7188
# step 6270: train loss 2.6571, val loss 2.7837
# step 6280: train loss 2.6929, val loss 2.7062
# step 6290: train loss 2.6495, val loss 2.7015
# step 6300: train loss 2.7111, val loss 2.9195
# step 6310: train loss 2.7374, val loss 2.7227
# step 6320: train loss 2.7172, val loss 2.7398
# step 6330: train loss 2.6850, val loss 2.7958
# step 6340: train loss 2.6465, val loss 2.7335
# step 6350: train loss 2.6524, val loss 2.7019
# step 6360: train loss 2.6766, val loss 2.7103
# step 6370: train loss 2.7227, val loss 2.8310
# step 6380: train loss 2.6757, val loss 2.7509
# step 6390: train loss 2.6924, val loss 2.7898
# step 6400: train loss 2.6567, val loss 2.6952
# step 6410: train loss 2.7288, val loss 2.7378
# step 6420: train loss 2.6731, val loss 2.7551
# step 6430: train loss 2.6955, val loss 2.7793
# step 6440: train loss 2.6551, val loss 2.7505
# step 6450: train loss 2.6773, val loss 2.6906
# step 6460: train loss 2.6835, val loss 2.6846
# step 6470: train loss 2.6351, val loss 2.7762
# step 6480: train loss 2.6208, val loss 2.8111
# step 6490: train loss 2.6876, val loss 2.7215
# step 6500: train loss 2.6619, val loss 2.6577
# step 6510: train loss 2.6515, val loss 2.6796
# step 6520: train loss 2.6413, val loss 2.6478
# step 6530: train loss 2.6971, val loss 2.8348
# step 6540: train loss 2.7078, val loss 2.7381
# step 6550: train loss 2.6721, val loss 2.6897
# step 6560: train loss 2.6283, val loss 2.6950
# step 6570: train loss 2.7353, val loss 2.7708
# step 6580: train loss 2.6111, val loss 2.7578
# step 6590: train loss 2.6726, val loss 2.6690
# step 6600: train loss 2.6172, val loss 2.7774
# step 6610: train loss 2.6685, val loss 2.7300
# step 6620: train loss 2.6934, val loss 2.6596
# step 6630: train loss 2.6465, val loss 2.7318
# step 6640: train loss 2.7228, val loss 2.8329
# step 6650: train loss 2.6328, val loss 2.7469
# step 6660: train loss 2.6669, val loss 2.6661
# step 6670: train loss 2.6561, val loss 2.7418
# step 6680: train loss 2.6209, val loss 2.6745
# step 6690: train loss 2.6136, val loss 2.7497
# step 6700: train loss 2.6271, val loss 2.6013
# step 6710: train loss 2.6591, val loss 2.7583
# step 6720: train loss 2.6418, val loss 2.6767
# step 6730: train loss 2.6737, val loss 2.6822
# step 6740: train loss 2.7117, val loss 2.7520
# step 6750: train loss 2.7321, val loss 2.6324
# step 6760: train loss 2.6933, val loss 2.7091
# step 6770: train loss 2.6225, val loss 2.7557
# step 6780: train loss 2.6747, val loss 2.7076
# step 6790: train loss 2.7198, val loss 2.6821
# step 6800: train loss 2.6666, val loss 2.6915
# step 6810: train loss 2.6015, val loss 2.7439
# step 6820: train loss 2.7123, val loss 2.7611
# step 6830: train loss 2.6853, val loss 2.7216
# step 6840: train loss 2.6637, val loss 2.6936
# step 6850: train loss 2.6796, val loss 2.7695
# step 6860: train loss 2.5804, val loss 2.7395
# step 6870: train loss 2.6268, val loss 2.6505
# step 6880: train loss 2.6382, val loss 2.7819
# step 6890: train loss 2.6496, val loss 2.7578
# step 6900: train loss 2.6990, val loss 2.6811
# step 6910: train loss 2.6325, val loss 2.7511
# step 6920: train loss 2.5879, val loss 2.7129
# step 6930: train loss 2.6577, val loss 2.7429
# step 6940: train loss 2.5754, val loss 2.6699
# step 6950: train loss 2.6513, val loss 2.6285
# step 6960: train loss 2.6202, val loss 2.5930
# step 6970: train loss 2.6057, val loss 2.6133
# step 6980: train loss 2.6491, val loss 2.7370
# step 6990: train loss 2.6343, val loss 2.6844
# step 7000: train loss 2.6946, val loss 2.6830
# step 7010: train loss 2.5521, val loss 2.7025
# step 7020: train loss 2.6537, val loss 2.7383
# step 7030: train loss 2.6170, val loss 2.6779
# step 7040: train loss 2.6584, val loss 2.5689
# step 7050: train loss 2.5540, val loss 2.7076
# step 7060: train loss 2.6662, val loss 2.6632
# step 7070: train loss 2.5638, val loss 2.6342
# step 7080: train loss 2.5985, val loss 2.6393
# step 7090: train loss 2.6106, val loss 2.6628
# step 7100: train loss 2.6449, val loss 2.6138
# step 7110: train loss 2.6881, val loss 2.7946
# step 7120: train loss 2.6302, val loss 2.7353
# step 7130: train loss 2.6459, val loss 2.9273
# step 7140: train loss 2.6327, val loss 2.6238
# step 7150: train loss 2.6082, val loss 2.7726
# step 7160: train loss 2.6194, val loss 2.6336
# step 7170: train loss 2.5593, val loss 2.7649
# step 7180: train loss 2.6417, val loss 2.6571
# step 7190: train loss 2.6750, val loss 2.6455
# step 7200: train loss 2.6362, val loss 2.6454
# step 7210: train loss 2.6342, val loss 2.6877
# step 7220: train loss 2.6061, val loss 2.7026
# step 7230: train loss 2.5654, val loss 2.6992
# step 7240: train loss 2.6236, val loss 2.6954
# step 7250: train loss 2.6360, val loss 2.5959
# step 7260: train loss 2.6701, val loss 2.7116
# step 7270: train loss 2.5979, val loss 2.6778
# step 7280: train loss 2.6137, val loss 2.7478
# step 7290: train loss 2.5954, val loss 2.6900
# step 7300: train loss 2.5621, val loss 2.6960
# step 7310: train loss 2.6079, val loss 2.6598
# step 7320: train loss 2.6475, val loss 2.6466
# step 7330: train loss 2.6390, val loss 2.6386
# step 7340: train loss 2.6085, val loss 2.6749
# step 7350: train loss 2.5847, val loss 2.7201
# step 7360: train loss 2.5686, val loss 2.6698
# step 7370: train loss 2.5883, val loss 2.6750
# step 7380: train loss 2.4795, val loss 2.5921
# step 7390: train loss 2.6852, val loss 2.6477
# step 7400: train loss 2.6101, val loss 2.7050
# step 7410: train loss 2.5743, val loss 2.6073
# step 7420: train loss 2.5938, val loss 2.6723
# step 7430: train loss 2.6178, val loss 2.6251
# step 7440: train loss 2.6499, val loss 2.6546
# step 7450: train loss 2.6082, val loss 2.7582
# step 7460: train loss 2.5734, val loss 2.6876
# step 7470: train loss 2.6211, val loss 2.5128
# step 7480: train loss 2.5988, val loss 2.7054
# step 7490: train loss 2.5547, val loss 2.6804
# step 7500: train loss 2.6735, val loss 2.6046
# step 7510: train loss 2.6077, val loss 2.6842
# step 7520: train loss 2.5456, val loss 2.6293
# step 7530: train loss 2.5386, val loss 2.6245
# step 7540: train loss 2.6210, val loss 2.7884
# step 7550: train loss 2.6288, val loss 2.6667
# step 7560: train loss 2.5277, val loss 2.7472
# step 7570: train loss 2.6353, val loss 2.7340
# step 7580: train loss 2.6095, val loss 2.6799
# step 7590: train loss 2.6836, val loss 2.6752
# step 7600: train loss 2.6145, val loss 2.6778
# step 7610: train loss 2.6105, val loss 2.5761
# step 7620: train loss 2.6790, val loss 2.6868
# step 7630: train loss 2.6130, val loss 2.6890
# step 7640: train loss 2.5853, val loss 2.6858
# step 7650: train loss 2.5160, val loss 2.8206
# step 7660: train loss 2.6593, val loss 2.7475
# step 7670: train loss 2.6264, val loss 2.6930
# step 7680: train loss 2.6071, val loss 2.5703
# step 7690: train loss 2.5928, val loss 2.7209
# step 7700: train loss 2.5625, val loss 2.6522
# step 7710: train loss 2.6147, val loss 2.6307
# step 7720: train loss 2.4883, val loss 2.6503
# step 7730: train loss 2.5529, val loss 2.6402
# step 7740: train loss 2.4791, val loss 2.6323
# step 7750: train loss 2.6359, val loss 2.7314
# step 7760: train loss 2.5328, val loss 2.6341
# step 7770: train loss 2.6363, val loss 2.6234
# step 7780: train loss 2.5426, val loss 2.7590
# step 7790: train loss 2.5455, val loss 2.5710
# step 7800: train loss 2.5789, val loss 2.6619
# step 7810: train loss 2.5982, val loss 2.7424
# step 7820: train loss 2.6857, val loss 2.6434
# step 7830: train loss 2.5435, val loss 2.6524
# step 7840: train loss 2.5507, val loss 2.5967
# step 7850: train loss 2.5274, val loss 2.7057
# step 7860: train loss 2.5328, val loss 2.6575
# step 7870: train loss 2.5827, val loss 2.6622
# step 7880: train loss 2.5196, val loss 2.6761
# step 7890: train loss 2.5536, val loss 2.5997
# step 7900: train loss 2.5341, val loss 2.6700
# step 7910: train loss 2.6262, val loss 2.6444
# step 7920: train loss 2.5829, val loss 2.6635
# step 7930: train loss 2.5009, val loss 2.6798
# step 7940: train loss 2.6604, val loss 2.6422
# step 7950: train loss 2.5205, val loss 2.6211
# step 7960: train loss 2.6037, val loss 2.5714
# step 7970: train loss 2.5768, val loss 2.6161
# step 7980: train loss 2.5237, val loss 2.5299
# step 7990: train loss 2.5993, val loss 2.6514
# step 8000: train loss 2.5368, val loss 2.7121
# step 8010: train loss 2.5352, val loss 2.6937
# step 8020: train loss 2.5782, val loss 2.7076
# step 8030: train loss 2.5658, val loss 2.6962
# step 8040: train loss 2.5842, val loss 2.6690
# step 8050: train loss 2.5138, val loss 2.6997
# step 8060: train loss 2.6221, val loss 2.7412
# step 8070: train loss 2.5057, val loss 2.6862
# step 8080: train loss 2.5304, val loss 2.6996
# step 8090: train loss 2.5609, val loss 2.5909
# step 8100: train loss 2.5675, val loss 2.5660
# step 8110: train loss 2.5544, val loss 2.6981
# step 8120: train loss 2.5224, val loss 2.6091
# step 8130: train loss 2.5188, val loss 2.6635
# step 8140: train loss 2.5225, val loss 2.6037
# step 8150: train loss 2.6138, val loss 2.6663
# step 8160: train loss 2.6175, val loss 2.7095
# step 8170: train loss 2.5242, val loss 2.6315
# step 8180: train loss 2.6360, val loss 2.5985
# step 8190: train loss 2.5379, val loss 2.7067
# step 8200: train loss 2.6004, val loss 2.6524
# step 8210: train loss 2.5665, val loss 2.4938
# step 8220: train loss 2.4978, val loss 2.6504
# step 8230: train loss 2.5264, val loss 2.8199
# step 8240: train loss 2.5526, val loss 2.6627
# step 8250: train loss 2.5632, val loss 2.7938
# step 8260: train loss 2.5752, val loss 2.5961
# step 8270: train loss 2.5292, val loss 2.5189
# step 8280: train loss 2.5710, val loss 2.5883
# step 8290: train loss 2.5874, val loss 2.7861
# step 8300: train loss 2.5680, val loss 2.6446
# step 8310: train loss 2.5959, val loss 2.5772
# step 8320: train loss 2.6630, val loss 2.5263
# step 8330: train loss 2.5451, val loss 2.5764
# step 8340: train loss 2.6076, val loss 2.5710
# step 8350: train loss 2.5630, val loss 2.5985
# step 8360: train loss 2.5455, val loss 2.7122
# step 8370: train loss 2.5497, val loss 2.6227
# step 8380: train loss 2.4569, val loss 2.5705
# step 8390: train loss 2.5851, val loss 2.6675
# step 8400: train loss 2.5345, val loss 2.7078
# step 8410: train loss 2.5553, val loss 2.6325
# step 8420: train loss 2.5741, val loss 2.6726
# step 8430: train loss 2.6098, val loss 2.8077
# step 8440: train loss 2.4855, val loss 2.6697
# step 8450: train loss 2.4832, val loss 2.5769
# step 8460: train loss 2.5848, val loss 2.6436
# step 8470: train loss 2.6407, val loss 2.6410
# step 8480: train loss 2.5658, val loss 2.5951
# step 8490: train loss 2.5483, val loss 2.6591
# step 8500: train loss 2.5833, val loss 2.6215
# step 8510: train loss 2.5207, val loss 2.6098
# step 8520: train loss 2.5832, val loss 2.5634
# step 8530: train loss 2.5815, val loss 2.5888
# step 8540: train loss 2.4722, val loss 2.6016
# step 8550: train loss 2.4829, val loss 2.6152
# step 8560: train loss 2.5190, val loss 2.6330
# step 8570: train loss 2.5348, val loss 2.4823
# step 8580: train loss 2.6112, val loss 2.6053
# step 8590: train loss 2.5643, val loss 2.5734
# step 8600: train loss 2.5228, val loss 2.6483
# step 8610: train loss 2.5325, val loss 2.6271
# step 8620: train loss 2.4769, val loss 2.6536
# step 8630: train loss 2.5824, val loss 2.6080
# step 8640: train loss 2.4917, val loss 2.6003
# step 8650: train loss 2.5786, val loss 2.5893
# step 8660: train loss 2.6231, val loss 2.5680
# step 8670: train loss 2.5331, val loss 2.6416
# step 8680: train loss 2.5629, val loss 2.6491
# step 8690: train loss 2.5007, val loss 2.6283
# step 8700: train loss 2.5602, val loss 2.5598
# step 8710: train loss 2.5691, val loss 2.6596
# step 8720: train loss 2.5493, val loss 2.5003
# step 8730: train loss 2.5862, val loss 2.6117
# step 8740: train loss 2.5408, val loss 2.5841
# step 8750: train loss 2.4856, val loss 2.6088
# step 8760: train loss 2.4654, val loss 2.5158
# step 8770: train loss 2.5914, val loss 2.5680
# step 8780: train loss 2.4827, val loss 2.5495
# step 8790: train loss 2.4932, val loss 2.5666
# step 8800: train loss 2.5192, val loss 2.6829
# step 8810: train loss 2.5466, val loss 2.6241
# step 8820: train loss 2.4970, val loss 2.5379
# step 8830: train loss 2.5401, val loss 2.5934
# step 8840: train loss 2.5355, val loss 2.5995
# step 8850: train loss 2.5302, val loss 2.7032
# step 8860: train loss 2.5448, val loss 2.5699
# step 8870: train loss 2.5346, val loss 2.5011
# step 8880: train loss 2.5712, val loss 2.5986
# step 8890: train loss 2.5547, val loss 2.6075
# step 8900: train loss 2.5000, val loss 2.5964
# step 8910: train loss 2.5101, val loss 2.6092
# step 8920: train loss 2.5042, val loss 2.4958
# step 8930: train loss 2.4266, val loss 2.6319
# step 8940: train loss 2.5204, val loss 2.6980
# step 8950: train loss 2.4730, val loss 2.5988
# step 8960: train loss 2.4822, val loss 2.5394
# step 8970: train loss 2.5275, val loss 2.6227
# step 8980: train loss 2.4832, val loss 2.6672
# step 8990: train loss 2.5204, val loss 2.5812
# step 9000: train loss 2.6200, val loss 2.5680
# step 9010: train loss 2.4969, val loss 2.5653
# step 9020: train loss 2.5042, val loss 2.6609
# step 9030: train loss 2.5222, val loss 2.5894
# step 9040: train loss 2.5287, val loss 2.5393
# step 9050: train loss 2.5490, val loss 2.6970
# step 9060: train loss 2.5343, val loss 2.5328
# step 9070: train loss 2.5363, val loss 2.6062
# step 9080: train loss 2.5949, val loss 2.5925
# step 9090: train loss 2.4777, val loss 2.6280
# step 9100: train loss 2.5159, val loss 2.5564
# step 9110: train loss 2.5749, val loss 2.5561
# step 9120: train loss 2.5453, val loss 2.5804
# step 9130: train loss 2.5498, val loss 2.6583
# step 9140: train loss 2.5074, val loss 2.5361
# step 9150: train loss 2.5805, val loss 2.5750
# step 9160: train loss 2.5497, val loss 2.5555
# step 9170: train loss 2.5006, val loss 2.5534
# step 9180: train loss 2.4587, val loss 2.5845
# step 9190: train loss 2.5441, val loss 2.5550
# step 9200: train loss 2.5078, val loss 2.5770
# step 9210: train loss 2.5137, val loss 2.5479
# step 9220: train loss 2.4701, val loss 2.5159
# step 9230: train loss 2.5158, val loss 2.5395
# step 9240: train loss 2.5981, val loss 2.6378
# step 9250: train loss 2.5394, val loss 2.5370
# step 9260: train loss 2.4803, val loss 2.6643
# step 9270: train loss 2.5515, val loss 2.5243
# step 9280: train loss 2.5105, val loss 2.4549
# step 9290: train loss 2.4050, val loss 2.5605
# step 9300: train loss 2.5926, val loss 2.5821
# step 9310: train loss 2.5483, val loss 2.5933
# step 9320: train loss 2.5061, val loss 2.5488
# step 9330: train loss 2.4670, val loss 2.5686
# step 9340: train loss 2.5042, val loss 2.5644
# step 9350: train loss 2.5910, val loss 2.5300
# step 9360: train loss 2.5765, val loss 2.5226
# step 9370: train loss 2.4608, val loss 2.6296
# step 9380: train loss 2.5302, val loss 2.6287
# step 9390: train loss 2.5788, val loss 2.5474
# step 9400: train loss 2.4994, val loss 2.5452
# step 9410: train loss 2.5672, val loss 2.5380
# step 9420: train loss 2.4867, val loss 2.5730
# step 9430: train loss 2.5842, val loss 2.5703
# step 9440: train loss 2.5498, val loss 2.5051
# step 9450: train loss 2.4870, val loss 2.5313
# step 9460: train loss 2.4936, val loss 2.5163
# step 9470: train loss 2.4575, val loss 2.5649
# step 9480: train loss 2.5866, val loss 2.5538
# step 9490: train loss 2.4833, val loss 2.5465
# step 9500: train loss 2.5924, val loss 2.5340
# step 9510: train loss 2.5348, val loss 2.6225
# step 9520: train loss 2.5978, val loss 2.5384
# step 9530: train loss 2.4401, val loss 2.6533
# step 9540: train loss 2.5304, val loss 2.5130
# step 9550: train loss 2.5163, val loss 2.6655
# step 9560: train loss 2.5277, val loss 2.5106
# step 9570: train loss 2.5303, val loss 2.6532
# step 9580: train loss 2.4876, val loss 2.6310
# step 9590: train loss 2.5195, val loss 2.6373
# step 9600: train loss 2.5264, val loss 2.5259
# step 9610: train loss 2.4643, val loss 2.5295
# step 9620: train loss 2.4984, val loss 2.5580
# step 9630: train loss 2.5124, val loss 2.5786
# step 9640: train loss 2.5485, val loss 2.6509
# step 9650: train loss 2.6084, val loss 2.5878
# step 9660: train loss 2.5016, val loss 2.6230
# step 9670: train loss 2.6127, val loss 2.6175
# step 9680: train loss 2.4703, val loss 2.5451
# step 9690: train loss 2.5550, val loss 2.6090
# step 9700: train loss 2.5570, val loss 2.5956
# step 9710: train loss 2.5810, val loss 2.5423
# step 9720: train loss 2.5244, val loss 2.5900
# step 9730: train loss 2.5503, val loss 2.5176
# step 9740: train loss 2.4284, val loss 2.5407
# step 9750: train loss 2.5080, val loss 2.7108
# step 9760: train loss 2.4982, val loss 2.6165
# step 9770: train loss 2.5456, val loss 2.5363
# step 9780: train loss 2.5186, val loss 2.5204
# step 9790: train loss 2.4878, val loss 2.5917
# step 9800: train loss 2.5129, val loss 2.5853
# step 9810: train loss 2.4824, val loss 2.5678
# step 9820: train loss 2.4795, val loss 2.5475
# step 9830: train loss 2.5507, val loss 2.4787
# step 9840: train loss 2.4628, val loss 2.4800
# step 9850: train loss 2.5541, val loss 2.5503
# step 9860: train loss 2.4751, val loss 2.5956
# step 9870: train loss 2.4996, val loss 2.4939
# step 9880: train loss 2.5426, val loss 2.6289
# step 9890: train loss 2.5455, val loss 2.6029
# step 9900: train loss 2.5270, val loss 2.5518
# step 9910: train loss 2.5231, val loss 2.6458
# step 9920: train loss 2.4963, val loss 2.6158
# step 9930: train loss 2.5595, val loss 2.5634
# step 9940: train loss 2.4894, val loss 2.5782
# step 9950: train loss 2.5352, val loss 2.5799
# step 9960: train loss 2.5282, val loss 2.5849
# step 9970: train loss 2.4908, val loss 2.6072
# step 9980: train loss 2.5331, val loss 2.5748
# step 9990: train loss 2.5253, val loss 2.6830

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
#  rairiome!,
#
# 1ezord s N1Aurintob fu es cttre acé!
# I, quretu'hJe Kc d'h!?tod! in phhaibisit:à?4 enda:

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = 
# define the Query layer
query = 
# define the Value layer
value =  
# apply each layer to the input
k =  # (B, T, head_size)
q =  # (B, T, head_size)
v =  # (B, T, head_size)
# compute the normalize product between Q and K 
weights =  # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = 
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
